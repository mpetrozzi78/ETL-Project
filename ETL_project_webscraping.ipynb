# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
URL = "https://www.indeed.com/jobs?q=data+analyst&l=San+Francisco%2C+CA"
#conducting a request of the stated URL above:
page = requests.get(URL)
page
# Out:
# <Response [200]>

# %%
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text,"html.parser")
#printing soup in a more structured tree format that makes for easier reading
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="/s/e884308/en_US.js" type="text/javascript">
#   </script>
#   <script>
#    window.indeed=window.indeed||{};indeed.crashtext=indeed.crashtext||{};indeed.crashtext.populate=indeed.crashtext.populate||function(c,g){var d=window[g];if(d){var e=d[""]||{},h=e.salt;if(e.hasOwnProperty("salt"))for(var b in c){for(var a=void 0,a=h,f=b.length;f;)a=33*a^b.charCodeAt(--f);a>>>=0;e.hasOwnProperty("id_length")&&(a=String(a).substring(0,e.id_length));d[a]=c[b]}else for(b in c)d[b]=[null].concat(c[b])}};indeed.crashtext.populate({"Save jobs and view them from any computer.":["Not ready to apply? Save job to apply later"],"You must sign in to save jobs:":["To do so:"]}, 'indeed.i18n.localeData')
#   </script>
#   <link href="/s/a3f9d47/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="http://rss.indeed.com/rss?q=data+analyst&amp;l=San+Francisco%2C+CA" rel="alternate" title="Data Analyst Jobs, Employment in San Francisco, CA" type="application/rss+xml"/>
#   <link href="/m/jobs?q=data+analyst&amp;l=San+Francisco%2C+CA" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/m/jobs?q=data+analyst&amp;l=San+Francisco%2C+CA" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
# window['closureReadyCallbacks'] = [];
# }
#
# function call_when_jsall_loaded(cb) {
# if (window['closureReady']) {
# cb();
# } else {
# window['closureReadyCallbacks'].push(cb);
# }
# }
#   </script>
#   <meta content="1" name="ppstriptst"/>
#   <script src="/s/abdb2cb/jobsearch-all-compiled.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var searchUID = '1dovhn2s62vhp001';
# var tk = '1dovhn2s62vhp001';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/www.indeed.com\/account\/login?dest=%2Fq-data-analyst-l-San-Francisco%2C-CA-jobs.html';
# var globalRegisterURL = 'https:\/\/www.indeed.com\/account\/register?dest=%2Fq-data-analyst-l-San-Francisco%2C-CA-jobs.html';
# var searchKey = 'dc59b31b09dc347a';
# var searchState = 'q=data+analyst&amp;l=San+Francisco%2C+CA';
# var searchQS = 'q=data+analyst&l=San+Francisco,+CA';
# var eventType = 'jobsearch';
# var locale = 'en_US';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1dovhn2s62vhp001&jsa=134'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1dovhn2s62vhp001&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
#   </script>
#   <script type="text/javascript">
#    function loadJSAsync( ) {
# for ( var i = 0; i < arguments.length; i++ ) {
# var url = arguments[i];
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.async = true;
# s.src = url;
# el.parentNode.insertBefore(s, el);
# })();
# }
# }
#   </script>
#   <meta content="684 Data Analyst jobs available in San Francisco, CA on Indeed.com. Apply to Data Analyst, Systems Analyst and more!" name="description"/>
#   <meta content="Data Analyst Jobs, Employment in San Francisco, CA, San Francisco, CA careers, San Francisco, CA employment, San Francisco, CA job listings, San Francisco, CA job search, San Francisco, CA search engine, work in San Francisco, CA" name="keywords"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/q-Data-Analyst-l-San-Francisco,-CA-jobs.html" rel="canonical"/>
#   <link href="/jobs?q=data+analyst&amp;l=San+Francisco%2C+CA&amp;start=10" rel="next">
#    <script src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/312e7676412af6e46d15/scripts/shim.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     var dcmPayload = 'jobse0;jobal0;viewj0;savej0;6927552';
# var indeedCsrfToken = '1rdu7RyViQDDkOjyPpU8yMkSj2SHC3pc';
# var hashedCsrfToken = 'af68ed9e06e62eca2ba13fe07e069300';
#    </script>
#    <style type="text/css">
#     .icl-Container,.icl-Grid-col{box-sizing:border-box}[dir=ltr] .icl-u-border,[dir=rtl] .icl-u-border{border:1px solid #ccc!important}[dir=ltr] .icl-u-borderBottom,[dir=rtl] .icl-u-borderBottom{border-bottom:1px solid #ccc!important}[dir=ltr] .icl-u-borderTop,[dir=rtl] .icl-u-borderTop{border-top:1px solid #ccc!important}[dir=ltr] .icl-u-borderNone,[dir=rtl] .icl-u-borderNone{border:none!important}[dir=ltr] .icl-u-bgColor--form,[dir=rtl] .icl-u-bgColor--form{background-color:#e8e8e8!important}[dir=ltr] .icl-u-visuallyHidden,[dir=rtl] .icl-u-visuallyHidden{border:0!important;clip:rect(0 0 0 0)!important;height:1px!important;margin:-1px!important;overflow:hidden!important;padding:0!important;position:absolute!important;width:1px!important}[dir=ltr] .icl-u-xs-hide,[dir=rtl] .icl-u-xs-hide{display:none!important}[dir=ltr] .icl-u-xs-block,[dir=rtl] .icl-u-xs-block{display:block!important}[dir=ltr] .icl-u-xs-inline,[dir=rtl] .icl-u-xs-inline{display:inline!important}[dir=ltr] .icl-u-xs-inlineBlock,[dir=rtl] .icl-u-xs-inlineBlock{display:inline-block!important}[dir=ltr] .icl-u-xs-floatLeft{float:left!important}[dir=ltr] .icl-u-xs-floatRight,[dir=rtl] .icl-u-xs-floatLeft{float:right!important}[dir=rtl] .icl-u-xs-floatRight{float:left!important}[dir=ltr] .icl-u-xs-horizontalCenter,[dir=rtl] .icl-u-xs-horizontalCenter{margin-left:auto!important;margin-right:auto!important}@media (min-width:30em){[dir=ltr] .icl-u-sm-hide,[dir=rtl] .icl-u-sm-hide{display:none!important}[dir=ltr] .icl-u-sm-block,[dir=rtl] .icl-u-sm-block{display:block!important}[dir=ltr] .icl-u-sm-inline,[dir=rtl] .icl-u-sm-inline{display:inline!important}[dir=ltr] .icl-u-sm-inlineBlock,[dir=rtl] .icl-u-sm-inlineBlock{display:inline-block!important}[dir=ltr] .icl-u-sm-floatLeft{float:left!important}[dir=ltr] .icl-u-sm-floatRight,[dir=rtl] .icl-u-sm-floatLeft{float:right!important}[dir=rtl] .icl-u-sm-floatRight{float:left!important}[dir=ltr] .icl-u-sm-horizontalCenter,[dir=rtl] .icl-u-sm-horizontalCenter{margin-left:auto!important;margin-right:auto!important}}@media (min-width:48em){[dir=ltr] .icl-u-md-hide,[dir=rtl] .icl-u-md-hide{display:none!important}[dir=ltr] .icl-u-md-block,[dir=rtl] .icl-u-md-block{display:block!important}[dir=ltr] .icl-u-md-inline,[dir=rtl] .icl-u-md-inline{display:inline!important}[dir=ltr] .icl-u-md-inlineBlock,[dir=rtl] .icl-u-md-inlineBlock{display:inline-block!important}[dir=ltr] .icl-u-md-floatLeft{float:left!important}[dir=ltr] .icl-u-md-floatRight,[dir=rtl] .icl-u-md-floatLeft{float:right!important}[dir=rtl] .icl-u-md-floatRight{float:left!important}[dir=ltr] .icl-u-md-horizontalCenter,[dir=rtl] .icl-u-md-horizontalCenter{margin-left:auto!important;margin-right:auto!important}}@media (min-width:62em){[dir=ltr] .icl-u-lg-hide,[dir=rtl] .icl-u-lg-hide{display:none!important}[dir=ltr] .icl-u-lg-block,[dir=rtl] .icl-u-lg-block{display:block!important}[dir=ltr] .icl-u-lg-inline,[dir=rtl] .icl-u-lg-inline{display:inline!important}[dir=ltr] .icl-u-lg-inlineBlock,[dir=rtl] .icl-u-lg-inlineBlock{display:inline-block!important}[dir=ltr] .icl-u-lg-floatLeft{float:left!important}[dir=ltr] .icl-u-lg-floatRight,[dir=rtl] .icl-u-lg-floatLeft{float:right!important}[dir=rtl] .icl-u-lg-floatRight{float:left!important}[dir=ltr] .icl-u-lg-horizontalCenter,[dir=rtl] .icl-u-lg-horizontalCenter{margin-left:auto!important;margin-right:auto!important}}@media (min-width:80em){[dir=ltr] .icl-u-xl-hide,[dir=rtl] .icl-u-xl-hide{display:none!important}[dir=ltr] .icl-u-xl-block,[dir=rtl] .icl-u-xl-block{display:block!important}[dir=ltr] .icl-u-xl-inline,[dir=rtl] .icl-u-xl-inline{display:inline!important}[dir=ltr] .icl-u-xl-inlineBlock,[dir=rtl] .icl-u-xl-inlineBlock{display:inline-block!important}[dir=ltr] .icl-u-xl-floatLeft{float:left!important}[dir=ltr] .icl-u-xl-floatRight,[dir=rtl] .icl-u-xl-floatLeft{float:right!important}[dir=rtl] .icl-u-xl-floatRight{float:left!important}[dir=ltr] .icl-u-xl-horizontalCenter,[dir=rtl] .icl-u-xl-horizontalCenter{margin-left:auto!i ...
# /*# sourceMappingURL=Grid.css.map*/
#    </style>
#    <style type="text/css">
#     .icl-Icon{box-sizing:border-box;display:inline-block;vertical-align:middle;height:3rem;width:3rem}.icl-Icon--input{display:inline-block;position:absolute;height:44px;width:40px;fill:#ccc;bottom:0}.icl-Icon--md{height:1.5rem;width:1.5rem}.icl-Icon--sm{height:1.125rem;width:1.125rem}[dir=ltr] .icl-Icon--right{margin-left:.2rem;right:0}[dir=rtl] .icl-Icon--right{margin-right:.2rem;left:0}[dir=ltr] .icl-Icon--left{margin-right:.2rem}[dir=rtl] .icl-Icon--left{margin-left:.2rem}.icl-Icon--black{fill:#000}.icl-Icon--blue{fill:#085ff7}.icl-Icon--grey{fill:#ccc}.icl-Icon--darkgrey{fill:#909090}.icl-Icon--orange{fill:#ff5a1f}.icl-Icon--white{fill:#fff}.icl-Icon--inheritColor{fill:currentColor}
# /*# sourceMappingURL=Icon.css.map*/
#    </style>
#    <style type="text/css">
#     body.janus #resultsCol .clickcard .jobtitle a,body.janus #resultsCol .clickcard a.jobtitle{text-decoration:none}body.janus #resultsCol .clickcard:hover .jobtitle a,body.janus #resultsCol .clickcard:hover a.jobtitle{text-decoration:underline}
#    </style>
#    <style type="text/css">
#     .jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !important}.jasxcustomfonttst-useGibson *{font-family:"Gibson", sans-serif !important}.jasxcustomfonttst-useAvenir *{font-family:"Avenir Next", sans-serif !important}#accessibilityBanner{position:absolute;left:-10000%;height:50px;width:100%;color:#000;font-size:13px;font-family:Arial;background-color:#F2F2F2;border-width:1px;border-color:#E6E6E6;line-height:50px}#accessibilityText{position:relative;left:12px;white-space:nowrap}#accessibilityClose{position:absolute;right:12px}.icl-Button--xl{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1.25rem;letter-spacing:-.1px;font-weight:700;line-height:1.3}[dir] .icl-Button--xl{padding-top:.5rem;padding-bottom:.5rem}[dir=ltr] .icl-Button--xl,[dir=rtl] .icl-Button--xl{padding-left:1.5rem;padding-right:1.5rem}.icl-Button,.icl-Button--lg{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1rem;letter-spacing:0;font-weight:700;line-height:1.38;line-height:1.125rem}[dir] .icl-Button,[dir] .icl-Button--lg{padding-top:1rem;padding-bottom:1rem}[dir=ltr] .icl-Button,[dir=ltr] .icl-Button--lg,[dir=rtl] .icl-Button,[dir=rtl] .icl-Button--lg{padding-left:1.5rem;padding-right:1.5rem}.icl-Button--md{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.875rem;letter-spacing:0;font-weight:700;line-height:1.43;line-height:1.5rem}[dir] .icl-Button--md{padding-top:.5rem;padding-bottom:.5rem}[dir=ltr] .icl-Button--md,[dir=rtl] .icl-Button--md{padding-left:1.5rem;padding-right:1.5rem}.icl-Button--sm{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.75rem;letter-spacing:0;font-weight:700;line-height:1.34;line-height:1.5rem}[dir] .icl-Button--sm{padding-top:.25rem;padding-bottom:.25rem}[dir=ltr] .icl-Button--sm,[dir=rtl] .icl-Button--sm{padding-left:1rem;padding-right:1rem}.icl-Button--xs{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.625rem;letter-spacing:0;font-weight:700;line-height:1.4;line-height:.875rem}[dir] .icl-Button--xs{padding-top:.125rem;padding-bottom:.125rem;padding-top:0}[dir=ltr] .icl-Button--xs,[dir=rtl] .icl-Button--xs{padding-left:.5rem;padding-right:.5rem}.icl-Button,.icl-Button--primary{box-sizing:border-box;display:inline-block;color:#fff;-webkit-font-smoothing:antialiased;overflow:hidden;text-overflow:ellipsis;text-decoration:none;white-space:nowrap;-webkit-highlight:none;-webkit-tap-highlight-color:transparent;-webkit-touch-callout:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}[dir] .icl-Button,[dir] .icl-Button--primary{margin:0;text-align:center;background-color:#085ff7;border:.125rem solid #085ff7;border-radius:6.25rem;background-repeat:repeat-x;cursor:pointer}[dir] .icl-Button--primary::-moz-focus-inner,[dir] .icl-Button::-moz-focus-inner{border:0}.icl-Button--primary:disabled,.icl-Button--primary:disabled:hover,.icl-Button:disabled,.icl-Button:disabled:hover{color:#ccc}[dir] .icl-Button--primary:disabled,[dir] .icl-Button--primary:disabled:hover,[dir] .icl-Button:disabled,[dir] .icl-Button:disabled:hover{cursor:default;background:#fff;border:.125rem solid #ececec}.icl-Button--primary:visited,.icl-Button:visited{color:#fff}.icl-Button--primary:active,.icl-Button--primary:focus,.icl-Button--primary:hover,.icl-Button:active,.icl-Button:focus,.icl-Button:hover{color:#fff;text-decoration:none}[dir] .icl-Button--primary:active,[dir] .icl-Button--primary:focus,[dir] .icl-Button--primary:hover,[dir] .icl-Button:active,[dir] .icl-Button:focus,[dir] .icl-Button:hover{background-color:#1497ff;border-color:#1497ff}.icl-Button--primary:focus,.icl-B ...
#    </style>
#    <style type="text/css">
#     span.salary-legal-disclaimer-icon{background-image:url('data:image/png;base64,...');vertical-align:middle;display:inline-block;background-size:13px 13px;width:13px;height:13px}span.salary-legal-disclaimer-icon:hover{cursor:pointer}.salary-legal-disclaimer-container-group{display:none;position:fixed;width:100%;height:100%;left:0;top:0;background-color:rgba(0,0,0,0.3);filter:progid:DXImageTransform.Microsoft.Gradient(GradientType=0,StartColorStr=#50000000,EndColorStr=#50000000);z-index:1000}.salary-legal-disclaimer-modal,.salary-legal-disclaimer-modal-QandA{position:absolute;box-sizing:border-box;width:500px;height:450px;left:0;right:0;top:0;bottom:0;margin:auto;background-color:#fff;padding:25px;overflow:auto;box-shadow:0 0 8px rgba(0,0,0,0.4)}.salary-legal-disclaimer-modal-QandA{height:430px}#salary-legal-disclaimer-container-distribution .salary-legal-disclaimer-modal{height:250px}.salary-legal-disclaimer-modal-close{position:absolute;right:15px;top:15px;width:16px;height:16px;opacity:.5;cursor:pointer}.salary-legal-disclaimer-modal-close:hover{opacity:1}.salary-legal-disclaimer-modal-close:before,.salary-legal-disclaimer-modal-close:after{display:inline-block;content:"";position:absolute;left:0;top:7px;width:16px;height:2px;background-color:#666}.salary-legal-disclaimer-modal-close:before{-webkit-transform:rotate(45deg);transform:rotate(45deg)}.salary-legal-disclaimer-modal-close:after{-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}.salary-legal-disclaimer-content{font:13px/1.4 Arial,sans-serif;color:black}.salary-legal-disclaimer-title{padding-bottom:25px;padding-top:5px;font-size:18px;font-weight:bold}.salary-legal-disclaimer-title-QandA{padding-top:5px;font-size:18px;font-weight:bold}.salary-legal-disclaimer-link-wrap{white-space:nowrap}.salary-legal-disclaimer-link{color:#00c}.icl-ButtonGroup{box-sizing:border-box;display:-ms-flexbox;display:flex}[dir] .icl-ButtonGroup .icl-Button--group{border-radius:0}[dir='ltr'] .icl-ButtonGroup .icl-Button--group{margin-right:0}[dir='rtl'] .icl-ButtonGroup .icl-Button--group{margin-left:0}[dir='ltr'] .icl-ButtonGroup .icl-Button--group:first-child{border-top-left-radius:6.25rem;border-bottom-left-radius:6.25rem;border-right-width:0}[dir='ltr'] .icl-ButtonGroup .icl-Button--group:last-child,[dir='rtl'] .icl-ButtonGroup .icl-Button--group:first-child{border-top-right-radius:6.25rem;border-bottom-right-radius:6.25rem;border-left-width:0}[dir='rtl'] .icl-ButtonGroup .icl-Button--group:last-child{border-top-left-radius:6.25rem;border-bottom-left-radius:6.25rem;border-right-width:0}[dir='ltr'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary{border-right-color:#0044e3}[dir='rtl'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary{border-left-color:#0044e3}[dir='ltr'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary:first-child{border-right:2px solid #0044e3;border-left-color:transparent}[dir='rtl'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary:first-child{border-left:2px solid #0044e3;border-right-color:transparent}[dir='ltr'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary:last-child{border-right-color:transparent}[dir='rtl'] .icl-ButtonGroup .icl-Button--group.icl-Button--primary:last-child{border-left-color:transparent}[dir='ltr'] .icl-ButtonGroup .icl-Button--group.icl-Button--secondary,[dir='ltr'] .icl-ButtonGroup .icl-Button--group.icl-Button--tertiary{border-left-width:0}[dir='rtl'] .icl-ButtonGroup .icl-Button--group.icl-Button--secondary,[dir='rtl'] .icl-ButtonGroup .icl-Button--group.icl-Button--tertiary{border-right-width:0}[dir] .icl-ButtonGroup .icl-Button--group.icl-Button--secondary:first-child,[dir] .icl-ButtonGroup .icl-Button--group.icl-Button--tertiary:first-child{border-width:.125rem}.icl-ButtonGroup .icl-Button--group:active,.icl-ButtonGroup .icl-Button--group:hover{color:#fff}[dir] .icl-ButtonGroup .icl-Button--group:active,[dir] .icl-ButtonGroup .icl-Button--group:hover{background-color:#1497ff;border-color:#1497ff} ...
#    </style>
#    <style type="text/css">
#     .salary-est-similar{color:#909090 !important;font-weight:normal !important}.salarySnippetDemphasize{padding-top:.2rem !important}
#    </style>
#    <style type="text/css">
#     #resultsCol { padding-top: 0; }
# .searchCount { margin-top: 6px; }
# .showing { padding-top: 9px; padding-bottom: 9px; }
#
# .brdr { height: 1px; overflow: hidden; background-color: #ccc; }
#
# /* Tall window sizes */
# @media only screen and (min-height:780px){
# .showing { padding-bottom: 0; }
# }
#
# /* Wide window sizes */
# @media only screen and (min-width:1125px){
# .brdr  { margin-left: 12px; margin-right: 12px; }
# }
#
# a,a:link,.link,.btn,.btn:hover{text-decoration:none}a:hover,.link:hover{text-decoration:underline}.dya-container a{text-decoration:underline !important}
#    </style>
#    <script>
#     initJavascriptGroups([[1,null],[1,null],[1,null],[3,null],[0,null],[2,null],[1,null],[1,null],[1,null],[-1,null],[1,["normalized"]],[1,["disableCaretAwareness"]],[-1,null],[-1,null],[-1,[]],[-1,null],[-1,["disableEmptyQueryByDefault"]],[-1,[]],[1,["noRQ"]],[10,["serp:enableEmptyQuery","serp:suggestOnFocus","requestOnFocus"]],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[1,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[3,null],[0,null],[1,null],[19,null],[-1,null],[2,null],[1,null],[0,null],[18,null],[1,null],[-1,null],[-1,null],[1,null],[1,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[3,null],[-1,null],[3,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,"AUSTIN_DUBLIN"],[-1,null],[1,null],[-1,null],[-1,null],[-1,["apply_deprecated"]],[-1,null],[-1,null],[-1,null],[2,null],[1,null],[-1,null],[-1,null],[1,null],[1,0],[-1,0],[-1,""],[-1,null],[4,null],[1,null],[17,null],[1,null],[13,null],[6,null],[-1,null],[1,null],[-1,null],[1,null],[4,null],[-1,null],[-1,null],[-1,null],[-1,null],[2,[8050739,8913675,9355776]],[-1,null],[2,null],[-1,null],[1,null],[1,null],[-1,null],[1,null],[1,null],[1,null],[1,null],[1,null],[1,null],[2,null],[0,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[1,null],[0,null],[1,null],[-1,null],[-1,null],[1,null],[1,null],[2,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[3,7],[0,null],[-1,null],[1,null],[1,null],[-1,null],[0,0.0],[2,null],[4,"Similar jobs pay {0}"],[1,null],[-1,null],[2,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,[]],[0,null],[-1,null],[-1,null],[-1,null],[2,null],[1,null],[-1,null],[1,null],[12,["24","10","action:sieveSponIaJobs"]],[-1,null],[-1,null],[-1,null],[-1,0],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[1,["jobse0","jobal0","viewj0","savej0","6927552"]],[-1,null],[-1,null],[1,null],[0,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[1,null],[2,[1769,61957709,20169]],[1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[1,["US","PR","CA"]],[-1,null],[2,null],[-1,null],[1,null],[3,null],[3,3],[-1,null],[-1,null],[1,null],[1,["change","30"]],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[4,null],[4,["1","2","22","1","144","1","552","1","3648","1","4392","1"]],[-1,null],[-1,-1],[1,null],[-1,null],[1,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[2,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,"1"],[4,0],[-1,null],[-1,{"width":0,"height":0}],[-1,null],[-1,null],[0,null],[-1,null],[1,null],[-1,null],[1,null],[1,null],[1,null],[1,null],[-1,null],[0,null],[1,null],[-1,null],[1,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[-1,[]],[-1,null],[-1,null],[-1,[]],[0,null],[-1,null],[-1,null],[-1,null],[2,null],[1,null],[2,{"adIds":[],"imgUrls":[]}],[1,null],[1,null],[-1,null],[-1,null],[-1,-1],[-1,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[2,null],[-1,null],[-1,null],[-1,null],[2,null],[3,null],[1,null],[1,null],[1,null],[0,0.0],[1,null],[-1,null],[2,null],[1,null],[1,null],[-1,null],[-1,null],[-1,0],[1,null],[-1,null],[-1,null],[1,null],[0,null],[1,null],[1,null],[5,{"categoriesToNegativeMatchSegments":"{\"dbcb2267-0d69-41e1-a456-7d93e66ee344\": [135]}","categoriesToPositiveMatchSegments":""}],[-1,null],[1,"1"],[0,null],[-1,null],[1,null],[1,null],[-1,[]],[-1,null],[2,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[0,null],[-1,null],[3,"aggsrf_v1"],[0,null],[1,null],[-1,null],[-1,null],[0,null],[-1,null],[1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[ ...
# setRecentJobStylingEnabled(false);
#
# function onLoadHandler() {
#
# document.js.reset();
# jobSeenInit('1dovhn2s62vhp001', [{
# 'jobClassName': 'result',
# 'scanIta': true,
# 'containsSponsored': true,
# 'context': ''
# }]);
#
# if ( document.radius_update ) { document.radius_update.reset(); }
#
#
# initJobsearchUnloadBeacon('1dovhn2s62vhp001');
# initApplyStartTimestamp();
#
# initDwellPerformanceLogging('1dovhn2s62vhp001', 'jasx');
# initWindowDwellLogging('jasx', '1dovhn2s62vhp001', 'serp');
#
# initSponsoredJobScreenerQuestions();
#
# initIndeedApply('https://www.indeed.com');
#
# }
#
# initLogInitialUserInteraction('1dovhn2s62vhp001', 'serp');
#
# window.onload = onLoadHandler;
#    </script>
#    <link href="android-app://com.indeed.android.jobsearch/https/www.indeed.com/m/jobs?q=data+analyst&amp;l=San+Francisco%2C+CA" rel="alternate"/>
#    <title>
#     Data Analyst Jobs, Employment in San Francisco, CA | Indeed.com
#    </title>
#    <style>
#    </style>
#    <style>
#    </style>
#    <style>
#    </style>
#    <style type="text/css">
#     .btn,.sg-btn{display:inline-block;padding:9px 15px;border:1px solid #9a99ac;border-bottom-color:#a2a2a2;-webkit-border-radius:6px;-moz-border-radius:6px;-ms-border-radius:6px;-o-border-radius:6px;border-radius:6px;background-color:#D9D9E2;background-image:-moz-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f8f8f9), to(#D9D9E2));background-image:-webkit-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:linear-gradient(to bottom, #f8f8f9, #D9D9E2);background-repeat:repeat-x;-webkit-box-shadow:0 1px 5px rgba(0,0,0,0.2);-moz-box-shadow:0 1px 5px rgba(0,0,0,0.2);-ms-box-shadow:0 1px 5px rgba(0,0,0,0.2);-o-box-shadow:0 1px 5px rgba(0,0,0,0.2);box-shadow:0 1px 5px rgba(0,0,0,0.2);color:#333;vertical-align:middle;text-align:center;text-decoration:none;text-shadow:0 1px #fff;font-weight:700;font-size:16px;font-family:"Helvetica Neue",Helvetica,Arial,"Lucida Grande",sans-serif;line-height:22px;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#fff8f8f9', endColorstr='#ffe6e6e6', GradientType=0);cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;-webkit-touch-callout:none;-webkit-highlight:none;-webkit-tap-highlight-color:transparent;text-overflow:ellipsis;white-space:nowrap;overflow:hidden}.btn.active,.btn.sg-active,.btn:active,.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.active,.sg-btn.sg-active,.sg-btn:active,.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{outline:none;background-color:#f8f8f9;color:#333}.btn:focus,.sg-btn:focus{outline:0;box-shadow:0 0 1px 0 #1642bb;-webkit-transition:box-shadow 0.2s linear;-moz-transition:box-shadow 0.2s linear;transition:box-shadow 0.2s linear}.btn.active,.btn.sg-active,.btn:active,.sg-btn.active,.sg-btn.sg-active,.sg-btn:active{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);-moz-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05)}.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:none;-moz-box-shadow:none;box-shadow:none;opacity:.65;filter:alpha(opacity=65);cursor:default}.btn-primary,.sg-btn-primary{border-color:#1642bb;background-color:#5585f2;background-image:-moz-linear-gradient(top, #6598ff, #2e5ad7);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#6598ff), to(#2e5ad7));background-image:-webkit-linear-gradient(top, #6598ff, #2e5ad7);background-image:linear-gradient(to bottom, #6598ff, #2e5ad7);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #0f2299;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff6598fe', endColorstr='#ff3c69e0', GradientType=0);zoom:1}.btn-primary.active,.btn-primary.sg-active,.btn-primary:active,.btn-primary.disabled,.btn-primary.sg-disabled,.btn-primary[disabled],.sg-btn-primary.active,.sg-btn-primary.sg-active,.sg-btn-primary:active,.sg-btn-primary.disabled,.sg-btn-primary.sg-disabled,.sg-btn-primary[disabled]{background-color:#2e5ad7;color:#F8F8F9}.btn-primary:focus,.sg-btn-primary:focus{box-shadow:0 0 1px 0 #000}.btn-special,.sg-btn-special{border-color:#ba3200;background-color:#5585f2;background-image:-moz-linear-gradient(top, #f60, #f14200);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f60), to(#f14200));background-image:-webkit-linear-gradient(top, #f60, #f14200);background-image:linear-gradient(to bottom, #f60, #f14200);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #000;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2 ...
#    </style>
#    <style>
#     body.janus{background-color:#f6f6f6}body.janus *,body.janus .jasxcustomfonttst-useAvenir *{font-family:"Helvetica Neue",Helvetica,Arial,sans-serif !important;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing:border-box}body.janus a,body.janus a:link{color:#2164f3}body.janus input::-webkit-contacts-auto-fill-button{visibility:hidden;display:none !important;pointer-events:none;position:absolute;right:0}body.janus .origin_site_link a{color:#085ff7}body.janus div#g_nav{border-bottom:2px solid #f6f6f6 !important;height:46px !important;margin-bottom:0}body.janus div#g_nav a{cursor:pointer;color:#4b4b4b !important;font-weight:400}body.janus div#g_nav#inboxLinkNavbar{font-weight:500 !important;font-size:12px !important;line-height:15.6px !important}body.janus div#g_nav .navBi a{font-size:12px;font-weight:500;position:relative;padding:12px 0;text-decoration:none}body.janus div#g_nav .navBi a:after{content:'';border-bottom:2px solid transparent;position:absolute;bottom:1px;left:0;right:0}body.janus div#g_nav .navBi a#userOptionsLabel{color:#2164f3 !important;font-size:12px;padding:12px 0}body.janus div#g_nav .navBi a:hover:after{border-color:#1497ff}body.janus div#g_nav .navBi a.selected{color:#000 !important;font-weight:700}body.janus div#g_nav .navBi a.selected:after{border-color:#2164f3}body.janus div#g_nav #userOptionsLabel{border-radius:15px 15px 0 0;border:2px solid transparent;margin-bottom:0 !important;display:flex;align-items:center}body.janus div#g_nav #userOptionsLabel .login_unconfirmed{display:flex;align-items:center}body.janus div#g_nav #userOptionsLabel .userLabelText{max-width:215px;text-overflow:ellipsis;overflow:hidden;text-decoration:none;margin-right:.25rem}body.janus div#g_nav #userOptionsLabel.active{border-color:#f6f6f6;padding:9px 12px !important}body.janus div#g_nav #userOptions{border:2px solid #f6f6f6;border-radius:15px 0 15px 15px;box-shadow:2px 3px 8px 0 rgba(0,0,0,0.08);padding:4px 0;margin-top:-1px}body.janus div#g_nav #userOptions .userOptionGroupHeader,body.janus div#g_nav #userOptions .userOptionItem a,body.janus div#g_nav #userOptions .userNameRepeat{display:block;min-width:220px;padding:2px 16px}body.janus div#g_nav #userOptions .userOptionGroup{border-top:2px solid #f6f6f6}body.janus div#g_nav table{height:55px;margin-top:-8px}body.janus div#g_nav td{padding:0 !important}body.janus .inwrapBorder{border:0 !important}body.janus .inwrapBorder .inwrapBorderTop{background-color:transparent !important;background-image:none !important;border:0 !important}body.janus .inwrapBorder .input_submit{border-radius:100px !important;font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:0.75rem;letter-spacing:0;font-weight:700;line-height:1.34;line-height:24px;padding:4px 1.5rem !important;background-color:#085ff7 !important;border:2px solid #085ff7 !important;color:#fff !important;font-weight:500;box-sizing:border-box}body.janus .inwrapBorder .input_submit:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #085ff7 !important;outline:0 !important}body.janus .inwrapBorder .input_submit:hover{background-color:#1497ff !important;border-color:#1497ff !important}body.janus .inwrapBorder .input_submit:hover:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #1497ff !important;outline:0 !important}body.janus .inwrapBorder .input_submit:disabled{color:#ccc !important;background-color:#fff !important;border-color:#fff !important}body.janus .inwrapBorder .input_submit.brandAdFollow,body.janus .inwrapBorder .input_submit.followButton{background-image:none !important}body.janus .inwrapBorder input.input_text{border:2px solid #ccc !important;box-sizing:border-box;background-color:#ececec}body.janus .inwrap{border:0 !important}body.janus #jobsearch .sl{color:#6f6f6f;margin-left:4px;padding-right:20px;font-size:0.75rem;line-height:1.67}body.janus #jobsearch td.npl{padding:0 !important}body.janus #jobsearch #what_label_top,body.janus #jobsearch #where_label_top{displ ...
#    </style>
#    <style>
#     body.janus #what_acdiv.acd{border:0 !important;border-color:inherit !important}body.janus .z-index-override{z-index:101 !important}body.janus #what_acdiv.acd,body.janus #acdiv.acd,body.janus #acdiv_where_alert.acd{border:0 !important;width:100% !important;z-index:101}body.janus #what_acdiv.acd ul,body.janus #acdiv.acd ul,body.janus #acdiv_where_alert.acd ul{border:2px solid #1497ff !important;border-radius:15px;box-shadow:2px 3px 8px 0 rgba(0,0,0,0.08);overflow:hidden}body.janus #what_acdiv.acd li.ac-active:hover,body.janus #what_acdiv.acd li.ac-active:active,body.janus #acdiv.acd li.ac-active:hover,body.janus #acdiv.acd li.ac-active:active,body.janus #acdiv_where_alert.acd li.ac-active:hover,body.janus #acdiv_where_alert.acd li.ac-active:active{color:#4b4b4b !important}body.janus .ac-active{color:#4b4b4b !important;background-color:#ececec !important}body.janus .ac-row{font-size:.875rem;padding:0.5rem 1rem}body.janus .ac-row .bold{color:#000}
#    </style>
#    <style type="text/css">
#     #resultsBody #pageContent #resultsCol .row .company,#resultsBody #pageContent #resultsCol .row .location{font-size:1rem !important;line-height:1.38 !important}#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer .serp-ResponsiveEmployer-heading,#resultsBody #pageContent #resultsCol .row .serp-ResumeMatch .serp-ResumeMatch-heading,#resultsBody #pageContent #resultsCol .row .salarySnippet .salary,#resultsBody #pageContent #resultsCol .row .snip .summary,#resultsBody #pageContent #resultsCol .row.unifiedRow .summary{font-size:0.875rem !important;line-height:1.25 !important}#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar span,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar a,#resultsBody #pageContent #resultsCol .row .result-link-bar-container .result-link-bar div{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .slNoUnderline{font-size:0.875rem !important;line-height:1 !important}#resultsBody #pageContent #resultsCol .row .jobtitle a{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row .jobtitle .new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}#resultsBody #pageContent #resultsCol .row a.jobtitle{font-size:1.125rem !important;line-height:1.5 !important}#resultsBody #pageContent #resultsCol .row span.new,#resultsBody #pageContent #resultsCol .row .iaP .iaLabel{font-size:0.875rem !important;line-height:1.25 !important}.ita-inline-job .sponsored{font-size:0.75rem !important}#resultsBody #pageContent #resultsCol .row .sdn{font-size:0.75rem !important}
#    </style>
#    <style type="text/css">
#     html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow,html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .summary,html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .new,html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .salary{font-size:13px !important}html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .company,html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .location{font-size:14px !important}html[lang="ja"] #resultsBody #pageContent #resultsCol .row.unifiedRow .title a{font-size:16px !important}#resultsBody #pageContent #resultsCol .row{padding-top:0.75rem !important;padding-bottom:0.75rem !important}#resultsBody #pageContent #resultsCol .row.unifiedRow{font-size:0.875rem;color:#4b4b4b !important}#resultsBody #pageContent #resultsCol .row.unifiedRow>*{padding-top:0.4rem;margin:0}#resultsBody #pageContent #resultsCol .row.unifiedRow .result-link-bar-container{padding:0}#resultsBody #pageContent #resultsCol .row.unifiedRow>.title,#resultsBody #pageContent #resultsCol .row.unifiedRow .sjcl{padding:0}[dir="rtl"] #resultsBody #pageContent #resultsCol .row.unifiedRow>.summary{padding-left:3.125rem}[dir="ltr"] #resultsBody #pageContent #resultsCol .row.unifiedRow>.summary{padding-right:3.125rem}#resultsBody #pageContent #resultsCol .row.unifiedRow>.tab-container{padding:0}#resultsBody #pageContent #resultsCol .row.unifiedRow>.tab-container>*:not(:empty){margin-top:0.5rem !important;margin-bottom:0 !important}#resultsBody #pageContent #resultsCol .row.unifiedRow>.cmiJobCategory-container{padding-top:0}#resultsBody #pageContent #resultsCol .row.unifiedRow>.new{padding-right:0}#resultsBody #pageContent #resultsCol .row .companyInfoWrapper,#resultsBody #pageContent #resultsCol .row .sjcl{padding-bottom:0.5rem}#resultsBody #pageContent #resultsCol .row .companyInfoWrapper:empty,#resultsBody #pageContent #resultsCol .row .sjcl:empty{padding-bottom:0 !important}#resultsBody #pageContent #resultsCol .row .paddedSummaryExperience .summary{padding-bottom:0.25rem}#resultsBody #pageContent #resultsCol .row .result-link-bar-container,#resultsBody #pageContent #resultsCol .row .jobCardFooter{padding-top:0.5rem}#resultsBody #pageContent #resultsCol .row .paddedSummary .summary+.showRecStatement{padding-top:0.25rem}#resultsBody #pageContent #resultsCol .row .paddedSummary+.iaWrapper{padding-top:0.25rem}#resultsBody #pageContent #resultsCol .row .JobTags-list+table tr .snip .salarySnippet,#resultsBody #pageContent #resultsCol .row .JobTags-list+tr .snip .salarySnippet,#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer+table tr .snip .salarySnippet,#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer+tr .snip .salarySnippet,#resultsBody #pageContent #resultsCol .row .serp-ResumeMatch+table tr .snip .salarySnippet,#resultsBody #pageContent #resultsCol .row .serp-ResumeMatch+tr .snip .salarySnippet{padding-top:0.5rem}#resultsBody #pageContent #resultsCol .row .JobTags-list+table tr .snip .summary:first-child,#resultsBody #pageContent #resultsCol .row .JobTags-list+tr .snip .summary:first-child,#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer+table tr .snip .summary:first-child,#resultsBody #pageContent #resultsCol .row .serp-ResponsiveEmployer+tr .snip .summary:first-child,#resultsBody #pageContent #resultsCol .row .serp-ResumeMatch+table tr .snip .summary:first-child,#resultsBody #pageContent #resultsCol .row .serp-ResumeMatch+tr .snip .summary:first-child{padding-top:0.25rem}#resultsBody #pageContent #resultsCol .row .salarySnippet+.paddedSummaryExperience .summary,#resultsBody #pageContent #resultsCol .row .salarySnippet+.paddedSummary .summary{padding-top:0.25rem}#resultsBody #pageContent #resultsCol .row .jobTypeLabelsWrapper+.paddedSummaryExperience .summary,#resultsBody #pageContent #resultsCol .row .jobTypeLabelsWrapper+.paddedSummary .summary{padding-top:0.25rem}#resultsBody ...
#    </style>
#    <style type="text/css">
#     .row .snip .salary,.row .sjcl .salarySnippet span,.row.unifiedRow .salarySnippet .salary{color:#000000 !important;font-size:0.875rem;font-weight:bold !important;line-height:1.43rem}
#    </style>
#    <style type="text/css">
#     .serp-chatAvailableIcon{margin-right:4px;height:16px;width:16px;content:url(data:image/svg+xml;base64,...)}.serp-chatEnabledEmployer{display:-ms-flexbox;display:-webkit-flex;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:2px 0}.serp-chatEnabledEmployer-heading{font-size:14px}.serpVj-chatAvailableVjIcon{float:right;padding-right:4px;padding-bottom:1.5px;content:url(data:image/svg+xml;base64,...)}.serpVj-chatBtn{display:inline-block;float:right;vertical-align:middle;padding:0;margin-top:.5rem;background:0;border:0}.serpVj-chatCalloutContainer{display:inline-flex;flex-direction:column;position:absolute;bottom:0;right:15px;padding:15px}.serpVJ-chatCalloutLink,.serpVJ-chatCalloutLink:focus,.serpVJ-chatCallout:visited{color:#2d2d2d}.serpVJ-chatCallout{max-width:200px;padding:15px;margin-bottom:8px;position:relative;float:right;font-size:12px;text-align:left;line-height:16px;cursor:pointer;background-color:#fff;border-top:#085ff7 solid 2px;border-radius:4px 4px 4px 0;box-shadow:0 4px 10px 0 rgba(0,0,0,0.25)}.serpVJ-chatCallout::before{content:"";width:0;height:0;border:1em solid transparent;position:absolute;right:0;bottom:-10px;border-left:18px solid #FFF}.serpVJ-chatCalloutClose{height:30px;float:right;text-align:center;padding:0 6px 6px 6px}.serpVJ-chatLineIcon{display:inline-block;content:url(...)}
#    </style>
#    <script type="text/javascript">
#     window['mosaicPlatformModel']= {
# 'mosaicReportContentProviderResponse': {
# 'providerId': 'mosaic-provider-reportcontent'
# }
# };
#    </script>
#    <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/522ed5bf7ea8b9097522/styles/index.css" rel="stylesheet">
#     <link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/ef34af94741f85222def/css/ReportContent-client.css" rel="stylesheet">
#      <link href="/images/favicon.ico" rel="shortcut icon"/>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="ltr jasxcustomfonttst-inactive janus" data-tn-application="jasx" data-tn-olth="41be357fa1c7dc26c5ee98836f8950b3" data-tn-originlogid="1dovhn2s62vhp001" data-tn-originlogtype="jobsearch">
#   <div id="accessibilityBanner">
#    <span id="accessibilityText">
#     Skip to
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">
#      Job Postings
#     </a>
#     ,
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#what" id="skipToSearch">
#      Search
#     </a>
#    </span>
#    <a id="accessibilityClose">
#     Close
#    </a>
#   </div>
#   <script type="text/javascript">
#    createTabBar('1dovhn2s62vhp001');
#   </script>
#   <script>
#    var sendMeaningfullyInteractive = false;
# var vjsExhibitionModel = new indeed.vjsExhibition('auxCol');
# var vjsStable = true;
# //For SERP jobs, the scope of these job are document
# var showDebug = false;
# var sd = showDebug ? '1' : undefined;
# var viewJobOnSerp = new indeed.vjs('1dovhn2s62vhp001', 'vjs', document, vjsExhibitionModel, sd, true);
# var vjk = viewJobOnSerp.getVJK();
# var vjFrom = viewJobOnSerp.getFrom();
# var vjTk = viewJobOnSerp.getTk();
# var indconvtk = '';
# var vjUrl = viewJobOnSerp.vjUrl(vjk, vjFrom, vjTk, indconvtk);
# var showVjOnSerp = vjsStable;
# var zrp = false;
# if ((zrp || !showVjOnSerp || window.innerWidth < 1200) && vjUrl) {
# window.location.replace(vjUrl);
# } else if (showVjOnSerp) {
# initializeTwoPane();
# }
# function initializeTwoPane() {
# var jobKeysWithInfo = {};
#
# jobKeysWithInfo['8869dbfc1538f643'] = true;
#
# jobKeysWithInfo['e20642e01de00b54'] = true;
#
# jobKeysWithInfo['2e3dbc6a348b27e6'] = true;
#
# jobKeysWithInfo['b444422939c7c3f1'] = true;
#
# jobKeysWithInfo['3a337d0d08aee6c3'] = true;
#
# jobKeysWithInfo['675e205406fd72ab'] = true;
#
# jobKeysWithInfo['e7d57b39ec86ad55'] = true;
#
# jobKeysWithInfo['b055fdedfea4960d'] = true;
#
# jobKeysWithInfo['36b1c51c252bbee9'] = true;
#
# jobKeysWithInfo['03681b7e6506c703'] = true;
#
# jobKeysWithInfo['f12ce2219af3100d'] = true;
#
# jobKeysWithInfo['080d7c049d19e209'] = true;
#
# jobKeysWithInfo['cb57d1c8ef082dba'] = true;
#
# jobKeysWithInfo['e227f2271c5f4381'] = true;
#
# jobKeysWithInfo['28b0d44de2d9fbf7'] = true;
#
# jobKeysWithInfo['30bbb5da5ff5476b'] = true;
#
# jobKeysWithInfo['fdd8098366a69b6e'] = true;
#
# if (vjk && !jobKeysWithInfo.hasOwnProperty(vjk)) {
# jobKeysWithInfo[vjk] = true;
# }
# viewJobOnSerp.preloadDescs(jobKeysWithInfo);
# window.bindAndRender = function () {
# if (showVjOnSerp) {
# viewJobOnSerp.bindJobKeys(jobKeysWithInfo, sendMeaningfullyInteractive);
# if (vjUrl) {
# viewJobOnSerp.renderOnJobKey(vjk, 'vjs', '1dovhn2s62vhp001', '', undefined, function () {
# window.location.replace(vjUrl);
# }, function() {
#
# restore('savedjobs');
#
# });
# }
# }
# };
# }
#   </script>
#   <script id="_indeed_gnav_config" type="application/json">
#    {"jsPath":"https://d3fw5vlhllyvee.cloudfront.net/dist/506ec3d29300cc908719/scripts/desktop_jobseeker_header_external.js","isDevMode":false,"isFallbackContent":false,"isEmployer":false,"primaryURL":"http://www.indeed.com/","requestURL":"http://www.indeed.com/q-data-analyst-l-San-Francisco,-CA-jobs.html?q=data+analyst\u0026l=San+Francisco,+CA","from":"gnav-menu-jobsearch--jasx","isShowSmallHeader":true,"desktopPageLinks":[{"text":"Find jobs","href":"http://www.indeed.com/","dataHref":"http://www.indeed.com/?from=gnav-jobsearch--jasx","isHighlighted":true},{"text":"Company reviews","href":"http://www.indeed.com/companies","dataHref":"http://www.indeed.com/companies?from=gnav-jobsearch--jasx","isHighlighted":false},{"text":"Find salaries","href":"http://www.indeed.com/salaries","dataHref":"http://www.indeed.com/salaries?from=gnav-jobsearch--jasx","isHighlighted":false}],"resumeLink":{"text":"Upload your resume","href":"http://www.indeed.com/promo/resume","dataHref":"http://www.indeed.com/promo/resume?from=gnav-jobsearch--jasx","isHighlighted":false},"variantToggleLink":{"text":"Employers / Post Job","href":"http://www.indeed.com/hire?co=US\u0026hl=en","dataHref":"http://www.indeed.com/hire?co=US\u0026hl=en\u0026from=gnav-menu-jobsearch--jasx\u0026ikw=gnav-header-hire\u0026isid=employerlink-US"},"country":"US","logoHref":"/?from=gnav-jobsearch--jasx","logoName":"","appName":"jobsearch--jasx","inboxApiHref":"https://inbox.indeed.com/api/getConversationCount?from=gnav-util-jobsearch--jasx\u0026gnavTK=1dovhn2s7blud801\u0026tk=\u0026co=US\u0026hl=en","inboxHref":"https://inbox.indeed.com/messages?from=gnav-util-jobsearch--jasx\u0026gnavTK=1dovhn2s7blud801\u0026tk=\u0026co=US\u0026hl=en","logRoute":"https://t.indeed.com/gnav/log?from=jobsearch--jasx-serp\u0026parentLogId=1dovhn2s7blud801\u0026hostAppTk=","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIcon":false,"inboxTestBucket":-1,"selectedIcon":"","shouldLowerNavIconMinWidth":true,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://www.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--jasx\u0026gnavTK=1dovhn2s7blud801\u0026tk=","notificationHref":"https://www.indeed.com/notifications?from=gnav-util-jobsearch--jasx\u0026gnavTK=1dovhn2s7blud801\u0026tk=\u0026co=US\u0026hl=en","isNotificationTestActive":false,"isShowNotificationIcon":false,"notificationTestBucket":-1,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb854","interactionLogType":"gnavInteraction","interactionLth":"87caa20c31fa9e447264b1615339f1ce","passportAccountText":"Sign in","passportAccountURL":"https://secure.indeed.com/account/login?hl=en_US\u0026co=US\u0026continue=http%3A%2F%2Fwww.indeed.com%2Fq-data-analyst-l-San-Francisco%2C-CA-jobs.html%3Fq%3Ddata+analyst%26l%3DSan+Francisco%2C+CA\u0026tmpl=desktop\u0026service=my\u0026from=gnav-util-jobsearch--jasx","showSecondaryStyleSignInButton":true,"language":"en","isShowLanguageSwitcher":false}
#   </script>
#   <style>
# ...
# //# sourceMappingURL=desktop_jobseeker_footer_inline.js.map
#        </script>
#        <script async="" src="https://d3fw5vlhllyvee.cloudfront.net/dist/c5300d49fe3a1b4da06b/scripts/desktop_jobseeker_footer_external.js">
#        </script>
#        <style type="text/css">
#         .icl-Button--xl{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1.25rem;letter-spacing:-.1px;font-weight:700;line-height:1.3}[dir] .icl-Button--xl{padding-top:.5rem;padding-bottom:.5rem}[dir=ltr] .icl-Button--xl,[dir=rtl] .icl-Button--xl{padding-left:1.5rem;padding-right:1.5rem}.icl-Button,.icl-Button--lg{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1rem;letter-spacing:0;font-weight:700;line-height:1.38;line-height:1.125rem}[dir] .icl-Button,[dir] .icl-Button--lg{padding-top:1rem;padding-bottom:1rem}[dir=ltr] .icl-Button,[dir=ltr] .icl-Button--lg,[dir=rtl] .icl-Button,[dir=rtl] .icl-Button--lg{padding-left:1.5rem;padding-right:1.5rem}.icl-Button--md{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.875rem;letter-spacing:0;font-weight:700;line-height:1.43;line-height:1.5rem}[dir] .icl-Button--md{padding-top:.5rem;padding-bottom:.5rem}[dir=ltr] .icl-Button--md,[dir=rtl] .icl-Button--md{padding-left:1.5rem;padding-right:1.5rem}.icl-Button--sm{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.75rem;letter-spacing:0;font-weight:700;line-height:1.34;line-height:1.5rem}[dir] .icl-Button--sm{padding-top:.25rem;padding-bottom:.25rem}[dir=ltr] .icl-Button--sm,[dir=rtl] .icl-Button--sm{padding-left:1rem;padding-right:1rem}.icl-Button--xs{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:.625rem;letter-spacing:0;font-weight:700;line-height:1.4;line-height:.875rem}[dir] .icl-Button--xs{padding-top:.125rem;padding-bottom:.125rem;padding-top:0}[dir=ltr] .icl-Button--xs,[dir=rtl] .icl-Button--xs{padding-left:.5rem;padding-right:.5rem}.icl-Button,.icl-Button--primary{box-sizing:border-box;display:inline-block;color:#fff;-webkit-font-smoothing:antialiased;overflow:hidden;text-overflow:ellipsis;text-decoration:none;white-space:nowrap;-webkit-highlight:none;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-touch-callout:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}[dir] .icl-Button,[dir] .icl-Button--primary{margin:0;text-align:center;background-color:#085ff7;border:.125rem solid #085ff7;border-radius:6.25rem;background-repeat:repeat-x;cursor:pointer}[dir] .icl-Button--primary::-moz-focus-inner,[dir] .icl-Button::-moz-focus-inner{border:0}.icl-Button--primary:disabled,.icl-Button--primary:disabled:hover,.icl-Button:disabled,.icl-Button:disabled:hover{color:#ccc}[dir] .icl-Button--primary:disabled,[dir] .icl-Button--primary:disabled:hover,[dir] .icl-Button:disabled,[dir] .icl-Button:disabled:hover{cursor:default;background:#fff;border:.125rem solid #ececec}.icl-Button--primary:visited,.icl-Button:visited{color:#fff}.icl-Button--primary:active,.icl-Button--primary:focus,.icl-Button--primary:hover,.icl-Button:active,.icl-Button:focus,.icl-Button:hover{color:#fff;text-decoration:none}[dir] .icl-Button--primary:active,[dir] .icl-Button--primary:focus,[dir] .icl-Button--primary:hover,[dir] .icl-Button:active,[dir] .icl-Button:focus,[dir] .icl-Button:hover{background-color:#1497ff;border-color:#1497ff}.icl-Button--primary:focus,.icl-Button:focus{-webkit-box-shadow:0 0 0 2px #fff,0 0 0 4px #085ff7;outline:0}[dir] .icl-Button--primary:focus,[dir] .icl-Button:focus{box-shadow:0 0 0 2px #fff,0 0 0 4px #085ff7}.icl-Button--secondary{box-sizing:border-box;display:inline-block;color:#085ff7;-webkit-font-smoothing:antialiased;overflow:hidden;text-overflow:ellipsis;text-decoration:none;white-space:nowrap;-webkit-highlight:none;-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-touch-callout:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}[dir] .icl-Button--secondary{margin:0;text-align:center;background-color:#fff;border:.125rem solid  ...
# /*# sourceMappingURL=Button.css.map*/
#        </style>
#        <div id="resumeCtaFooter" style="height:64px;">
#         <div style="position:absolute;width:100%;">
#          <style type="text/css">
#           .footerCta {
#                         text-align:center;
#                         margin:0px;
#                         font-size:15px;
#                         width:100%;
#                     }
#
#                     .footerCta.blueBar {
#                         background-color:#2164f3;
#                         color:#ffffff;
#                     }
#
#                     .footerCta.greyBar {
#                         background-color:#ebebeb;
#                         color:#000000;
#                     }
#
#                     div.content >table {
#                         margin-bottom: 4em;
#                     }
#          </style>
#          <script type="text/javascript">
#           if(null !== call_when_jsall_loaded) {call_when_jsall_loaded(function() {if(!!window.logPromoImpression) {window.logPromoImpression('trk.origin=jobsearch&trk.variant=FooterGrayBelow&trk.pos=below&trk.tk=1dovhn2s62vhp001', 'resume');}})}
#          </script>
#          <div class="footerCta greyBar">
#           Let Employers Find You
#           <style type="text/css">
#            .cta_button {
#             text-decoration:none !important;
#             margin: 12px !important;
#         }
#
#         .cta_button.blue  {
#             color: #f8f8f9 !important;
#         }
#
#         .cta_button.grey {
#             color: #000000 !important;
#         }
#
#         .cta_button.uploaded {
#             border-radius: 100px !important;
#             font-size: 12px;
#             line-height: 16px;
#             text-align: center;
#             padding: 8px;
#         }
#
#         .cta_button.continue {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #195ff7 !important;
#             width: 163px;
#         }
#
#         .cta_button.accept {
#             color: #ffffff !important;
#             background-color: #085ff7 !important;
#             border: 2px solid #085ff7 !important;
#             width: 106px;
#             display: inline-block;
#         }
#
#         .cta_button.back {
#             color: #085ff7 !important;
#             background-color: #ffffff !important;
#             border: 2px solid #cccccc !important;
#             width: 106px;
#             margin-left: -4px !important;
#         }
#           </style>
#           <span dir="ltr">
#            <a class="icl-Button icl-Button--primary icl-Button--sm cta_button blue" href="/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch" onclick="if(!!window.logPromoClick) {window.logPromoClick('trk.origin=jobsearch&amp;trk.variant=FooterGrayBelow&amp;trk.pos=below&amp;trk.tk=1dovhn2s62vhp001', 'resume','/promo/resume?from=bottomResumeCTAjobsearch&amp;trk.origin=jobsearch');}">
#             Upload Your Resume
#            </a>
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </td>
#    </tr>
#   </table>
#   <script type="text/javascript">
#    <!--
#
# logJSVPing('jsv', '1dovhn2s62vhp001');
# function jsall_loaded() {
#
#
# initProcessLeftoverDwellEntries();
#
# detectBrowserState('jobsearch', '1dovhn2s62vhp001');
#
# initLogTiming('jobsearch', '1dovhn2s62vhp001');
# attachSjBlock('');
# attachJaBlock('');
# }
# if (window['closureReady'] === true) {
# jsall_loaded();
# }
# //-->
#   </script>
#   <script type="text/javascript">
#    PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-6927552">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'DC-6927552');
#   </script>
#   <script type="text/javascript">
#    var ga_domains = [];
# ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
# (function (i, s, o, g, r, a, m) {
# i['GoogleAnalyticsObject'] = r;
# i[r] = i[r] || function () {
# (i[r].q = i[r].q || []).push(arguments)
# }, i[r].l = 1 * new Date();
# a = s.createElement(o),
# m = s.getElementsByTagName(o)[0];
# a.async = 1;
# a.src = g;
# m.parentNode.insertBefore(a, m)
# })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# var ga = ga || [];
# ga('create', 'UA-90780-1', 'auto', {
# 'allowLinker': true
# });
# ga('require', 'linkid');
# ga('require', 'linker');
# ga('linker:autoLink', ga_domains, false, true);
# ga('require', 'displayfeatures');
# ga('send', 'pageview');
#
# (function () {
# if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
# for (var i in PENDING_ANALYTICS_VARS) {
# ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
# }
# }
# })();
#   </script>
#   <script>
#    window._comscore = window._comscore || [];
# window._comscore.push({ c1: "2", c2: "6486505", c4:"www.indeed.com/q-data-analyst-l-San-Francisco,-CA-jobs.html", c15:"1dovhn2r02vhp000"});
# (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=www.indeed.com%2Fq-data-analyst-l-San-Francisco%2C-CA-jobs.html&amp;c15=1dovhn2r02vhp000&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
#   </noscript>
#   <script id="mosaic-init-data" type="text/javascript">
#    window.mosaic= window.mosaic || {};
#     window.mosaic.providers={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/76d84e62f1e1fbdeb4aa/js/ReportContent-client.js","platformJs":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/d69cef2198e57a0ee479/scripts/index.js"};
#     window.mosaic.providerErrors={};
#     window.mosaic.provideri18N={"mosaic-provider-reportcontent":"https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/i18n/7583e37bf3cc4e47c2d0/en_US.js"};
#     window.mosaic.lazyProviders={"mosaic-provider-reportcontent":"\u003cdiv class\u003d\"reportcontent-injection-wrapper\"\u003e\u003c/div\u003e"};
#     window.mosaic.cssResetProviders={"mosaic-provider-reportcontent":false}
#     window.mosaic.zonedProviders={}
#     window.mosaic.webpackPublicPath="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist"
#   </script>
#   <script id="mosaic-data" type="text/javascript">
#    window.mosaic.providerData={};
# window.mosaic.initialData = {"logTypes":{"jsuipPlatformInitError":"4327faee2bbb67f4e7f2185701a52e54","mosaicPlatformLoadRecovery":"cee115a2f7013215fe1cde93caa21161","mosaicProviderSeen":"e3926cc0a343f384f2e5e6dfc540016a","jsuipProviderLoadTimings":"fb7274d51fc7a04d450086c83a40cc6a","jsuipProviderExecutionError":"211e778edbde5e164fd5f14dd23e6115","jsuipAction":"d5973eb3ad332b3608839e9bbed7d867","jsuipPlatformLoadError":"c74c8d65f1d6f620ddce517edd3faa40","jsuipProviderLoadError":"61c37c1721757c82be5e97b1fff8d1c2"},"platformLogTk":"1dovhn2sd2vhp000","logTk":"1dovhn2s62vhp001","platformId":"jasx","env":"PRODUCTION","pageId":"serp"};
#
# window.mosaic.providerData["mosaic-provider-reportcontent"]={"userKey":null,"hostId":"jasx","pageId":"serp","ctk":"1dovhn2r02vhp000","country":"US","language":"en","userAgent":"python-requests/2.22.0","mobvjtk":"1dovhn2s62vhp001","isMobile":false,"indeedcsrftoken":"1rdu7RyViQDDkOjyPpU8yMkSj2SHC3pc","isLoggedIn":false,"isConfirmed":true,"reportContentConfig":{"tripledesSecretKey":"@rez9876|abc2005!0x0FEED","isIndeedMobileProctorGroup":true}};
#   </script>
#   <script async="" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/2d4060e6ff50c9287833/scripts/loadProviders.js">
#   </script>
#   <script>
#    window['sendPageLoadEndPing'] = function(pageId, tk, st) {var validPageIds = ['viewjob', 'serp']; if (!!Image && validPageIds.indexOf(pageId) > -1 && !!tk && !!st) {var href = '/rpc/pageLoadEnd?pageId=' + pageId + '&tk=' + tk + '&st=' + st + '&__=' + Math.random(); var img = new Image(); img.src = href;}}; window['sendPageLoadEndPing']("serp", "1dovhn2s62vhp001", "1573016800134");
#   </script>
#  </body>
# </html>

# %%
# Grab the job posting we are interested in 
job_vacancy = soup.find_all(name="div", attrs={"class":"jobsearch-SerpJobCard"})
print(job_vacancy)
# Out:
# [<div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="317290037" data-empn="1090180593285777" data-jk="36b1c51c252bbee9" id="pj_36b1c51c252bbee9">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DqyGUh-HCNdSeW2HskvWfFhBlHvIPqm0w48cXiMBVrfdP2nuWE5MZLbgJwd_FfGduCp3h2-jSgBsq0HMqcxtGvNlnW_tRVkqO9SqQZGPuKtgzpp0V132Klpt-P1vAcKqdwhE9583cgdphuxwTqXm9zqwl_hjBnc2NwXqOixz-Peiym4TKhYeDEGJZ_jlifwv19UhNnzKJ59Ud4EhCGgzlVkeYIiFG-XryS1SUswLQnwm_UGwVwA8Med8Wtd3xQVXcIrP0ugqWR70e81JYjYFHcJAby5xQL9tIyJVioipwzeLjfvXz8CYETMGkqbMOstqRIsjHemp5KkCIkmTehp4vok2RHkODbgNSK6oG-RBexrXUmqQ4ZM01za2uL5Y_iIP1G501wB-P0qpvwuOz2Mj7bF0vil8Amkh4qjeR3gxXSrXh-lFRmUenuV_bJfgdShWY=&amp;p=0&amp;fvj=1&amp;vjs=3" id="sja0" onclick="setRefineByCookie([]); sjoc('sja0', 0); convCtr('SJ')" onmousedown="sjomd('sja0'); clk('sja0');" rel="noopener nofollow" target="_blank" title="Growth Data Analyst">
# Growth <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Hubhaus" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=36b1c51c252bbee9&amp;jcid=7a2f348b0f7f7b8c')" rel="noopener" target="_blank">
# HubHaus</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Hubhaus/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Growth+Data+Analyst&amp;fromjk=36b1c51c252bbee9&amp;jcid=7a2f348b0f7f7b8c');" rel="noopener" target="_blank" title="Hubhaus reviews">
# <span class="ratingsContent">
# 3.0<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_36b1c51c252bbee9" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA</div>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td><td class="jobCardShelfItem"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 16 16" width="16"><rect fill="#DB183F" height="16" rx="8" width="16"></rect><g clip-path="url(#clip0)"><path clip-rule="evenodd" d="M7.99515 3.20001C5.34555 3.20001 3.19995 5.35041 3.19995 8.00001C3.19995 10.6496 5.34555 12.8 7.99515 12.8C10.6496 12.8 12.8 10.6496 12.8 8.00001C12.8 5.35041 10.6496 3.20001 7.99515 3.20001ZM7.99995 11.84C5.87835 11.84 4.15995 10.1216 4.15995 8.00001C4.15995 5.87841 5.87835 4.16001 7.99995 4.16001C10.1216 4.16001 11.84 5.87841 11.84 8.00001C11.84 10.1216 10.1216 11.84 7.99995 11.84Z" fill="white" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M8.24002 5.60001H7.52002V8.48001L10.04 9.99201L10.4 9.40161L8.24002 8.12001V5.60001Z" fill="white" fill-rule="evenodd"></path></g><defs><clippath><rect fill="white" height="9.6" transform="translate(3.19995 3.20001)" width="9.6"></rect></clippath></defs></svg></span>Urgently hiring</td></tr></table><div class="summary">
# We are a small, fast growing startup in the co-living space that is expanding rapidly. We'll continue our rapid expansion over the next year as we push into new…</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_0"><a class="sl resultLink save-job-link" href="#" id="sj_36b1c51c252bbee9" onclick="changeJobState('36b1c51c252bbee9', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_36b1c51c252bbee9" style="display:none;"></div><script>if (!window['sj_result_36b1c51c252bbee9']) {window['sj_result_36b1c51c252bbee9'] = {};}window['sj_result_36b1c51c252bbee9']['showSource'] = false; window['sj_result_36b1c51c252bbee9']['source'] = "Indeed"; window['sj_result_36b1c51c252bbee9']['loggedIn'] = false; window['sj_result_36b1c51c252bbee9']['showMyJobsLinks'] = false;window['sj_result_36b1c51c252bbee9']['undoAction'] = "unsave";window['sj_result_36b1c51c252bbee9']['jobKey'] = "36b1c51c252bbee9"; window['sj_result_36b1c51c252bbee9']['myIndeedAvailable'] = true; window['sj_result_36b1c51c252bbee9']['showMoreActionsLink'] = window['sj_result_36b1c51c252bbee9']['showMoreActionsLink'] || false; window['sj_result_36b1c51c252bbee9']['resultNumber'] = 0; window['sj_result_36b1c51c252bbee9']['jobStateChangedToSaved'] = false; window['sj_result_36b1c51c252bbee9']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_36b1c51c252bbee9']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_36b1c51c252bbee9']['saveJobFailed'] = false; window['sj_result_36b1c51c252bbee9']['removeJobFailed'] = false; window['sj_result_36b1c51c252bbee9']['requestPending'] = false; window['sj_result_36b1c51c252bbee9']['notesEnabled'] = false; window['sj_result_36b1c51c252bbee9']['currentPage'] = "serp"; window['sj_result_36b1c51c252bbee9']['sponsored'] = true;window['sj_result_36b1c51c252bbee9']['showSponsor'] = true;window['sj_result_36b1c51c252bbee9']['reportJobButtonEnabled'] = false; window['sj_result_36b1c51c252bbee9']['showMyJobsHired'] = false; window['sj_result_36b1c51c252bbee9']['showSaveForSponsored'] = true; window['sj_result_36b1c51c252bbee9']['showJobAge'] = true; window['sj_result_36b1c51c252bbee9']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="298488622" data-empn="1968454616528517" data-jk="f12ce2219af3100d" id="pj_f12ce2219af3100d">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ChKcuee4zN09_YQT3MPCNUn5-ck1FYX2SSl6c1cZx7rI0bO_p3fs0WRKx-6Or3MvHSDq3z28aGq-xZ9amidO7_JHqlgq6ZVSUwROqf2hgYg1q3yY04Isjj8xIA0Fxb_FFJlDxd3p62YowI_CzwisZucMYz1-9RRLUj--HVa09loLlD2LW-NqP4cbwrYTN5lXwYjjQR9uQCReCqJXs7cIL4y9p3_dpJdRwiErtXk9uGvmhobtKacj6ZopXeMjdVM3DAkgHzJ-OOS998ivMDEcfBvlsN_6JaumBdHK88MWJZin8-f-pc4XhcF72KAQ2JtpDzuhTwLkORM-IiChcFFuTkdF4d1ec3ttg3Ljb7fCYVZze-8JWKowcpP8lIg_RqMasLzVt699j86w==&amp;p=1&amp;fvj=0&amp;vjs=3" id="sja1" onclick="setRefineByCookie([]); sjoc('sja1', 0); convCtr('SJ')" onmousedown="sjomd('sja1'); clk('sja1');" rel="noopener nofollow" target="_blank" title="Financial Data Analyst, Tax">
# Financial <b>Data</b> <b>Analyst</b>, Tax</a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Lyft" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=f12ce2219af3100d&amp;jcid=56da7c20e66eb0dc')" rel="noopener" target="_blank">
# Lyft</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Lyft/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Financial+Data+Analyst%2C+Tax&amp;fromjk=f12ce2219af3100d&amp;jcid=56da7c20e66eb0dc');" rel="noopener" target="_blank" title="Lyft reviews">
# <span class="ratingsContent">
# 3.5<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_f12ce2219af3100d" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA</div>
# </div>
# <div class="summary">
# Extremely detail oriented and highly organized. At Lyft, community is what we are and it's what we do. It's what makes us different.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_1"><a class="sl resultLink save-job-link" href="#" id="sj_f12ce2219af3100d" onclick="changeJobState('f12ce2219af3100d', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_f12ce2219af3100d" style="display:none;"></div><script>if (!window['sj_result_f12ce2219af3100d']) {window['sj_result_f12ce2219af3100d'] = {};}window['sj_result_f12ce2219af3100d']['showSource'] = false; window['sj_result_f12ce2219af3100d']['source'] = "Lyft"; window['sj_result_f12ce2219af3100d']['loggedIn'] = false; window['sj_result_f12ce2219af3100d']['showMyJobsLinks'] = false;window['sj_result_f12ce2219af3100d']['undoAction'] = "unsave";window['sj_result_f12ce2219af3100d']['jobKey'] = "f12ce2219af3100d"; window['sj_result_f12ce2219af3100d']['myIndeedAvailable'] = true; window['sj_result_f12ce2219af3100d']['showMoreActionsLink'] = window['sj_result_f12ce2219af3100d']['showMoreActionsLink'] || false; window['sj_result_f12ce2219af3100d']['resultNumber'] = 1; window['sj_result_f12ce2219af3100d']['jobStateChangedToSaved'] = false; window['sj_result_f12ce2219af3100d']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_f12ce2219af3100d']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_f12ce2219af3100d']['saveJobFailed'] = false; window['sj_result_f12ce2219af3100d']['removeJobFailed'] = false; window['sj_result_f12ce2219af3100d']['requestPending'] = false; window['sj_result_f12ce2219af3100d']['notesEnabled'] = false; window['sj_result_f12ce2219af3100d']['currentPage'] = "serp"; window['sj_result_f12ce2219af3100d']['sponsored'] = true;window['sj_result_f12ce2219af3100d']['showSponsor'] = true;window['sj_result_f12ce2219af3100d']['reportJobButtonEnabled'] = false; window['sj_result_f12ce2219af3100d']['showMyJobsHired'] = false; window['sj_result_f12ce2219af3100d']['showSaveForSponsored'] = true; window['sj_result_f12ce2219af3100d']['showJobAge'] = true; window['sj_result_f12ce2219af3100d']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="319841877" data-empn="1662621414528498" data-jk="b055fdedfea4960d" id="pj_b055fdedfea4960d">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AyE5oQkcsghHb3t9CWF8AkXmk4x0jqUWCmid953uIQ2Z-NGEpZA8i3hD6K08tNDlY_b9nT83CUCux8uJrUoIasor-BkD_Nfvl-NTsRw24A8Hcu_cdIOVf8IWAzTKQC8AEfiy0tcUqhmv1LeoJ3Dr6GiGeK7ezpSaoVBOV1OJ-HMP29jkMCg9jMlvrv3Y-bU552RSISa91DF56iT1GdZXwi9pnWi3CqHvbF7bpadbEZWu5qhi2-vrcDv6wCY3OjNPzvwCNv_8xGg9Z7Aqmgh8OT8j5sxs42TAWHcB7lNTRmiiTHmJx67HEXNSj5YC1iat2dUgO0bf88p3nGt0MJAffrf50PUlj882vfMfvXHi-zAhM0V8lLKX57LObfWugLjcRizhWorVxzMZ0s49TD5Bu3tOevMjsFXUVhMbQALDREWpV4wCTDHO6_b0TgErrJNYFWwlq25EyQrA==&amp;p=2&amp;fvj=1&amp;vjs=3" id="sja2" onclick="setRefineByCookie([]); sjoc('sja2', 1); convCtr('SJ')" onmousedown="sjomd('sja2'); clk('sja2');" rel="noopener nofollow" target="_blank" title="Business Analyst">
# Business <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# Aaratechinc</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_b055fdedfea4960d" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA</div>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $55,000 - $70,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td></tr></table><div class="summary">
# Must have CUSTOMER FACING Experience. Bachelor's Degree in appropriate field of study or equivalent work experience.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="date">2 days ago</span><span class="tt_set" id="tt_set_2"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_b055fdedfea4960d" onclick="changeJobState('b055fdedfea4960d', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_b055fdedfea4960d" style="display:none;"></div><script>if (!window['sj_result_b055fdedfea4960d']) {window['sj_result_b055fdedfea4960d'] = {};}window['sj_result_b055fdedfea4960d']['showSource'] = false; window['sj_result_b055fdedfea4960d']['source'] = "Indeed"; window['sj_result_b055fdedfea4960d']['loggedIn'] = false; window['sj_result_b055fdedfea4960d']['showMyJobsLinks'] = false;window['sj_result_b055fdedfea4960d']['undoAction'] = "unsave";window['sj_result_b055fdedfea4960d']['relativeJobAge'] = "2 days ago";window['sj_result_b055fdedfea4960d']['jobKey'] = "b055fdedfea4960d"; window['sj_result_b055fdedfea4960d']['myIndeedAvailable'] = true; window['sj_result_b055fdedfea4960d']['showMoreActionsLink'] = window['sj_result_b055fdedfea4960d']['showMoreActionsLink'] || false; window['sj_result_b055fdedfea4960d']['resultNumber'] = 2; window['sj_result_b055fdedfea4960d']['jobStateChangedToSaved'] = false; window['sj_result_b055fdedfea4960d']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_b055fdedfea4960d']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_b055fdedfea4960d']['saveJobFailed'] = false; window['sj_result_b055fdedfea4960d']['removeJobFailed'] = false; window['sj_result_b055fdedfea4960d']['requestPending'] = false; window['sj_result_b055fdedfea4960d']['notesEnabled'] = false; window['sj_result_b055fdedfea4960d']['currentPage'] = "serp"; window['sj_result_b055fdedfea4960d']['sponsored'] = true;window['sj_result_b055fdedfea4960d']['showSponsor'] = true;window['sj_result_b055fdedfea4960d']['reportJobButtonEnabled'] = false; window['sj_result_b055fdedfea4960d']['showMyJobsHired'] = false; window['sj_result_b055fdedfea4960d']['showSaveForSponsored'] = true; window['sj_result_b055fdedfea4960d']['showJobAge'] = true; window['sj_result_b055fdedfea4960d']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="316221048" data-empn="210908886952977" data-jk="3a337d0d08aee6c3" id="pj_3a337d0d08aee6c3">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0DhVAxkc_TxySVbUOs6bxWYWOfhmDTNcVTjFFBAY1FXZz6G2ZVf9e4MmWYQM85EDW9KRpHPkjoMBNb6Ih4o2OQaXTNkoSdIwq6qaKinm5BiHjqo6Kw_LOXW7PqzwRwRfmkoifXVrojpQ0moi_PStD8xI-uKqLcHiqUtMVUtgMQStkHhYNKzVFmIWqRlqJYiwk_P9IPbHO6cLe7D3S3WmNvFWyB3AttJm4zTKRNB90onRZ5tbhpc2I34bnLkoA3sN9O_JiYSpsziueGB-igy7iyzkyO9qRwV4EJU63Y0jZ2Jlu5jkIBhf5CXKJortWoLI_x_PG4PLvWJzNLKhSFqHrtJUgeJDR1-AYbvCwY3vRyAIQNx_t_6snoHsCucsY0JwE04LWfKnGYmabJwjkueQVOZaG2kQeMHs2c8hh4UYbdwz1TTGBlOygMRBuhKxZ8K_wS6fq7lBxGTw9a_Owld2qzplf8vIn2LvvldKkTIypIYs-CIu3WnHLFwdNkoOFsLz9qHeHr3ZkqM5Wbs-zPWVpS9qXjgDkxeQ_NzCEG9FqwF3UMJHzZwrqffJKIQiSJenuaSBAIrx8MUXgpYqzHdvahICwVPgIPQWbI=&amp;p=3&amp;fvj=1&amp;vjs=3" id="sja3" onclick="setRefineByCookie([]); sjoc('sja3', 0); convCtr('SJ')" onmousedown="sjomd('sja3'); clk('sja3');" rel="noopener nofollow" target="_blank" title="Data Analyst">
# <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# Seen by Indeed</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_3a337d0d08aee6c3" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA</div>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td></tr></table><div class="summary">
# Seen by Indeed is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_3"><a class="sl resultLink save-job-link" href="#" id="sj_3a337d0d08aee6c3" onclick="changeJobState('3a337d0d08aee6c3', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_3a337d0d08aee6c3" style="display:none;"></div><script>if (!window['sj_result_3a337d0d08aee6c3']) {window['sj_result_3a337d0d08aee6c3'] = {};}window['sj_result_3a337d0d08aee6c3']['showSource'] = false; window['sj_result_3a337d0d08aee6c3']['source'] = "Seen by Indeed"; window['sj_result_3a337d0d08aee6c3']['loggedIn'] = false; window['sj_result_3a337d0d08aee6c3']['showMyJobsLinks'] = false;window['sj_result_3a337d0d08aee6c3']['undoAction'] = "unsave";window['sj_result_3a337d0d08aee6c3']['jobKey'] = "3a337d0d08aee6c3"; window['sj_result_3a337d0d08aee6c3']['myIndeedAvailable'] = true; window['sj_result_3a337d0d08aee6c3']['showMoreActionsLink'] = window['sj_result_3a337d0d08aee6c3']['showMoreActionsLink'] || false; window['sj_result_3a337d0d08aee6c3']['resultNumber'] = 3; window['sj_result_3a337d0d08aee6c3']['jobStateChangedToSaved'] = false; window['sj_result_3a337d0d08aee6c3']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_3a337d0d08aee6c3']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_3a337d0d08aee6c3']['saveJobFailed'] = false; window['sj_result_3a337d0d08aee6c3']['removeJobFailed'] = false; window['sj_result_3a337d0d08aee6c3']['requestPending'] = false; window['sj_result_3a337d0d08aee6c3']['notesEnabled'] = false; window['sj_result_3a337d0d08aee6c3']['currentPage'] = "serp"; window['sj_result_3a337d0d08aee6c3']['sponsored'] = true;window['sj_result_3a337d0d08aee6c3']['showSponsor'] = true;window['sj_result_3a337d0d08aee6c3']['reportJobButtonEnabled'] = false; window['sj_result_3a337d0d08aee6c3']['showMyJobsHired'] = false; window['sj_result_3a337d0d08aee6c3']['showSaveForSponsored'] = true; window['sj_result_3a337d0d08aee6c3']['showJobAge'] = true; window['sj_result_3a337d0d08aee6c3']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="313922127" data-empn="4625892391790901" data-jk="ed504bec0cb9fe87" id="pj_ed504bec0cb9fe87">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AL2auT42O7iYTwqh1ZF5cG-Ce2d5PysuD3KtagDfmHI-91DJ46Gd957ylnWY37jkTffByCFnlprcAjXyBHGWndHmlo145BwMASTUzL_gs3pV1wh9Qb3Bb4vRRZdzQG7XQYIKSguhXfe6Dynu48fbFO3x2hpX1rJJS_ez2TslIGVIDFc1WMh20gR8HuKo72kHxjBrxA2oKabGyFioL7_44LPJ9MNuGfYHEW7Qi7o7a8lItIQ-sjIFEkpmBDqLUl-865rDogUt69P10SgdHPg3WeTnhPmUCI5wwlMZrpKYeM3MGES3ybalgjDSzvcs_6Xhk314uoj9kxhO9vYTluubO6qG6cvmMr0aL7UJ_Pi7LJhPyeP7-iqLWCFf2UYNcoBo2wT7MUSZdzkmhNwIVnQQapcbWOGJtVj08X48OYUwOrq-VHojFYWg2K&amp;p=4&amp;fvj=1&amp;vjs=3" id="sja4" onclick="setRefineByCookie([]); sjoc('sja4', 0); convCtr('SJ')" onmousedown="sjomd('sja4'); clk('sja4');" rel="noopener nofollow" target="_blank" title="GIS Data Analyst">
# GIS <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Tanko-Lighting" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ed504bec0cb9fe87&amp;jcid=84eae699b8a520e1')" rel="noopener" target="_blank">
# Tanko Lighting</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Tanko-Lighting/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=GIS+Data+Analyst&amp;fromjk=ed504bec0cb9fe87&amp;jcid=84eae699b8a520e1');" rel="noopener" target="_blank" title="Tanko Lighting reviews">
# <span class="ratingsContent">
# 3.4<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_ed504bec0cb9fe87" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA 94124 <span style="font-size: smaller">(Bayview area)</span></div>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td></tr></table><div class="summary">
# Tanko Lighting is looking for a rock star. Our professional services team needs someone who can tackle massive amounts of data one day, then turn around and…</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_4"><a class="sl resultLink save-job-link" href="#" id="sj_ed504bec0cb9fe87" onclick="changeJobState('ed504bec0cb9fe87', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_ed504bec0cb9fe87" style="display:none;"></div><script>if (!window['sj_result_ed504bec0cb9fe87']) {window['sj_result_ed504bec0cb9fe87'] = {};}window['sj_result_ed504bec0cb9fe87']['showSource'] = false; window['sj_result_ed504bec0cb9fe87']['source'] = "Indeed"; window['sj_result_ed504bec0cb9fe87']['loggedIn'] = false; window['sj_result_ed504bec0cb9fe87']['showMyJobsLinks'] = false;window['sj_result_ed504bec0cb9fe87']['undoAction'] = "unsave";window['sj_result_ed504bec0cb9fe87']['jobKey'] = "ed504bec0cb9fe87"; window['sj_result_ed504bec0cb9fe87']['myIndeedAvailable'] = true; window['sj_result_ed504bec0cb9fe87']['showMoreActionsLink'] = window['sj_result_ed504bec0cb9fe87']['showMoreActionsLink'] || false; window['sj_result_ed504bec0cb9fe87']['resultNumber'] = 4; window['sj_result_ed504bec0cb9fe87']['jobStateChangedToSaved'] = false; window['sj_result_ed504bec0cb9fe87']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_ed504bec0cb9fe87']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_ed504bec0cb9fe87']['saveJobFailed'] = false; window['sj_result_ed504bec0cb9fe87']['removeJobFailed'] = false; window['sj_result_ed504bec0cb9fe87']['requestPending'] = false; window['sj_result_ed504bec0cb9fe87']['notesEnabled'] = false; window['sj_result_ed504bec0cb9fe87']['currentPage'] = "serp"; window['sj_result_ed504bec0cb9fe87']['sponsored'] = true;window['sj_result_ed504bec0cb9fe87']['showSponsor'] = true;window['sj_result_ed504bec0cb9fe87']['reportJobButtonEnabled'] = false; window['sj_result_ed504bec0cb9fe87']['showMyJobsHired'] = false; window['sj_result_ed504bec0cb9fe87']['showSaveForSponsored'] = true; window['sj_result_ed504bec0cb9fe87']['showJobAge'] = true; window['sj_result_ed504bec0cb9fe87']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="30bbb5da5ff5476b" data-tn-component="organicJob" id="p_30bbb5da5ff5476b">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=30bbb5da5ff5476b&amp;fccid=b806b5fae6a94a1d&amp;vjs=3" id="jl_30bbb5da5ff5476b" onclick="setRefineByCookie([]); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="noopener nofollow" target="_blank" title="Associate Product Data Analyst">
# Associate Product <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Minted" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=30bbb5da5ff5476b&amp;jcid=09ac38a1b52546f8')" rel="noopener" target="_blank">
# MINTED LLC</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Minted/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Associate+Product+Data+Analyst&amp;fromjk=30bbb5da5ff5476b&amp;jcid=09ac38a1b52546f8');" rel="noopener" target="_blank" title="Minted reviews">
# <span class="ratingsContent">
# 3.9<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_30bbb5da5ff5476b" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA 94133 <span style="font-size: smaller">(Russian Hill area)</span></span>
# </div>
# <div class="summary">
# Obsessive attention to detail with a knack for pattern recognition. Manage and maintain production database and other environments used for testing.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_5"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_30bbb5da5ff5476b" onclick="changeJobState('30bbb5da5ff5476b', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_5" onclick="toggleMoreLinks('30bbb5da5ff5476b'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_30bbb5da5ff5476b" style="display:none;"></div><script>if (!window['result_30bbb5da5ff5476b']) {window['result_30bbb5da5ff5476b'] = {};}window['result_30bbb5da5ff5476b']['showSource'] = false; window['result_30bbb5da5ff5476b']['source'] = "MINTED LLC"; window['result_30bbb5da5ff5476b']['loggedIn'] = false; window['result_30bbb5da5ff5476b']['showMyJobsLinks'] = false;window['result_30bbb5da5ff5476b']['undoAction'] = "unsave";window['result_30bbb5da5ff5476b']['relativeJobAge'] = "Just posted";window['result_30bbb5da5ff5476b']['jobKey'] = "30bbb5da5ff5476b"; window['result_30bbb5da5ff5476b']['myIndeedAvailable'] = true; window['result_30bbb5da5ff5476b']['showMoreActionsLink'] = window['result_30bbb5da5ff5476b']['showMoreActionsLink'] || true; window['result_30bbb5da5ff5476b']['resultNumber'] = 5; window['result_30bbb5da5ff5476b']['jobStateChangedToSaved'] = false; window['result_30bbb5da5ff5476b']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['result_30bbb5da5ff5476b']['basicPermaLink'] = "https://www.indeed.com"; window['result_30bbb5da5ff5476b']['saveJobFailed'] = false; window['result_30bbb5da5ff5476b']['removeJobFailed'] = false; window['result_30bbb5da5ff5476b']['requestPending'] = false; window['result_30bbb5da5ff5476b']['notesEnabled'] = true; window['result_30bbb5da5ff5476b']['currentPage'] = "serp"; window['result_30bbb5da5ff5476b']['sponsored'] = false;window['result_30bbb5da5ff5476b']['reportJobButtonEnabled'] = false; window['result_30bbb5da5ff5476b']['showMyJobsHired'] = false; window['result_30bbb5da5ff5476b']['showSaveForSponsored'] = false; window['result_30bbb5da5ff5476b']['showJobAge'] = true; window['result_30bbb5da5ff5476b']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('30bbb5da5ff5476b'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/jobs?q=Minted+LLC&amp;l=San+Francisco,+CA&amp;nc=jasx">MINTED LLC jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=30bbb5da5ff5476b&amp;from=serp-more');">Data Analyst salaries in San Francisco, CA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Minted/about" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=30bbb5da5ff5476b&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=09ac38a1b52546f8');">MINTED LLC</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Minted.html">Minted</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="e20642e01de00b54" data-tn-component="organicJob" id="p_e20642e01de00b54">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/InfoObjects-Inc/jobs/Data-Analyst-Month-e20642e01de00b54?fccid=8e7392b3400e87c3&amp;vjs=3" id="jl_e20642e01de00b54" onclick="setRefineByCookie([]); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="noopener nofollow" target="_blank" title="Data Analyst Part time (30 hrs Week) +1 Month">
# <b>Data</b> <b>Analyst</b> Part time (30 hrs Week) +1 Month</a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# InfoObjects Inc</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_e20642e01de00b54" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA</span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td><td class="jobCardShelfItem"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 16 16" width="16"><rect fill="#DB183F" height="16" rx="8" width="16"></rect><g clip-path="url(#clip0)"><path clip-rule="evenodd" d="M7.99515 3.20001C5.34555 3.20001 3.19995 5.35041 3.19995 8.00001C3.19995 10.6496 5.34555 12.8 7.99515 12.8C10.6496 12.8 12.8 10.6496 12.8 8.00001C12.8 5.35041 10.6496 3.20001 7.99515 3.20001ZM7.99995 11.84C5.87835 11.84 4.15995 10.1216 4.15995 8.00001C4.15995 5.87841 5.87835 4.16001 7.99995 4.16001C10.1216 4.16001 11.84 5.87841 11.84 8.00001C11.84 10.1216 10.1216 11.84 7.99995 11.84Z" fill="white" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M8.24002 5.60001H7.52002V8.48001L10.04 9.99201L10.4 9.40161L8.24002 8.12001V5.60001Z" fill="white" fill-rule="evenodd"></path></g><defs><clippath><rect fill="white" height="9.6" transform="translate(3.19995 3.20001)" width="9.6"></rect></clippath></defs></svg></span>Urgently hiring</td></tr></table><div class="summary">
# Manually going through sales files. Come in and build out certain macros. Automate some of the workflow. 1 year xp with macros, doesn't really care how much xp.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Today</span><span class="tt_set" id="tt_set_6"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_e20642e01de00b54" onclick="changeJobState('e20642e01de00b54', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_6" onclick="toggleMoreLinks('e20642e01de00b54'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_e20642e01de00b54" style="display:none;"></div><script>if (!window['result_e20642e01de00b54']) {window['result_e20642e01de00b54'] = {};}window['result_e20642e01de00b54']['showSource'] = false; window['result_e20642e01de00b54']['source'] = "Indeed"; window['result_e20642e01de00b54']['loggedIn'] = false; window['result_e20642e01de00b54']['showMyJobsLinks'] = false;window['result_e20642e01de00b54']['undoAction'] = "unsave";window['result_e20642e01de00b54']['relativeJobAge'] = "Today";window['result_e20642e01de00b54']['jobKey'] = "e20642e01de00b54"; window['result_e20642e01de00b54']['myIndeedAvailable'] = true; window['result_e20642e01de00b54']['showMoreActionsLink'] = window['result_e20642e01de00b54']['showMoreActionsLink'] || true; window['result_e20642e01de00b54']['resultNumber'] = 6; window['result_e20642e01de00b54']['jobStateChangedToSaved'] = false; window['result_e20642e01de00b54']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['result_e20642e01de00b54']['basicPermaLink'] = "https://www.indeed.com"; window['result_e20642e01de00b54']['saveJobFailed'] = false; window['result_e20642e01de00b54']['removeJobFailed'] = false; window['result_e20642e01de00b54']['requestPending'] = false; window['result_e20642e01de00b54']['notesEnabled'] = true; window['result_e20642e01de00b54']['currentPage'] = "serp"; window['result_e20642e01de00b54']['sponsored'] = false;window['result_e20642e01de00b54']['reportJobButtonEnabled'] = false; window['result_e20642e01de00b54']['showMyJobsHired'] = false; window['result_e20642e01de00b54']['showSaveForSponsored'] = false; window['result_e20642e01de00b54']['showJobAge'] = true; window['result_e20642e01de00b54']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('e20642e01de00b54'); return false;" title="Close"></a><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/jobs?q=Infoobjects+Inc&amp;l=San+Francisco,+CA&amp;nc=jasx">InfoObjects Inc jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=e20642e01de00b54&amp;from=serp-more');">Data Analyst salaries in San Francisco, CA</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Infoobjects-Inc-1.html">InfoObjects Inc</a> - <a href="/forum/job/Data-Analyst.html">Data Analyst</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="cb57d1c8ef082dba" data-tn-component="organicJob" id="p_cb57d1c8ef082dba">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cb57d1c8ef082dba&amp;fccid=b806b5fae6a94a1d&amp;vjs=3" id="jl_cb57d1c8ef082dba" onclick="setRefineByCookie([]); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="noopener nofollow" target="_blank" title="Associate Product Data Analyst">
# Associate Product <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Minted" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=cb57d1c8ef082dba&amp;jcid=b806b5fae6a94a1d')" rel="noopener" target="_blank">
# Minted</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Minted/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Associate+Product+Data+Analyst&amp;fromjk=cb57d1c8ef082dba&amp;jcid=b806b5fae6a94a1d');" rel="noopener" target="_blank" title="Minted reviews">
# <span class="ratingsContent">
# 3.9<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_cb57d1c8ef082dba" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA 94133 <span style="font-size: smaller">(Russian Hill area)</span></span>
# </div>
# <div class="summary">
# Support Engineering with data needs, debugging, testing, tools, and automation. Support Merchandising and execute product data audits.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_7"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_cb57d1c8ef082dba" onclick="changeJobState('cb57d1c8ef082dba', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_7" onclick="toggleMoreLinks('cb57d1c8ef082dba'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_cb57d1c8ef082dba" style="display:none;"></div><script>if (!window['result_cb57d1c8ef082dba']) {window['result_cb57d1c8ef082dba'] = {};}window['result_cb57d1c8ef082dba']['showSource'] = false; window['result_cb57d1c8ef082dba']['source'] = "Minted"; window['result_cb57d1c8ef082dba']['loggedIn'] = false; window['result_cb57d1c8ef082dba']['showMyJobsLinks'] = false;window['result_cb57d1c8ef082dba']['undoAction'] = "unsave";window['result_cb57d1c8ef082dba']['relativeJobAge'] = "Just posted";window['result_cb57d1c8ef082dba']['jobKey'] = "cb57d1c8ef082dba"; window['result_cb57d1c8ef082dba']['myIndeedAvailable'] = true; window['result_cb57d1c8ef082dba']['showMoreActionsLink'] = window['result_cb57d1c8ef082dba']['showMoreActionsLink'] || true; window['result_cb57d1c8ef082dba']['resultNumber'] = 7; window['result_cb57d1c8ef082dba']['jobStateChangedToSaved'] = false; window['result_cb57d1c8ef082dba']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['result_cb57d1c8ef082dba']['basicPermaLink'] = "https://www.indeed.com"; window['result_cb57d1c8ef082dba']['saveJobFailed'] = false; window['result_cb57d1c8ef082dba']['removeJobFailed'] = false; window['result_cb57d1c8ef082dba']['requestPending'] = false; window['result_cb57d1c8ef082dba']['notesEnabled'] = true; window['result_cb57d1c8ef082dba']['currentPage'] = "serp"; window['result_cb57d1c8ef082dba']['sponsored'] = false;window['result_cb57d1c8ef082dba']['reportJobButtonEnabled'] = false; window['result_cb57d1c8ef082dba']['showMyJobsHired'] = false; window['result_cb57d1c8ef082dba']['showSaveForSponsored'] = false; window['result_cb57d1c8ef082dba']['showJobAge'] = true; window['result_cb57d1c8ef082dba']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cb57d1c8ef082dba'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/q-Minted-l-San-Francisco,-CA-jobs.html">Minted jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=cb57d1c8ef082dba&amp;from=serp-more');">Data Analyst salaries in San Francisco, CA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Minted/about" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=cb57d1c8ef082dba&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=b806b5fae6a94a1d');">Minted</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Minted.html">Minted</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="03681b7e6506c703" data-tn-component="organicJob" id="p_03681b7e6506c703">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/company/Apex-Limited,LLC/jobs/Data-Analyst-03681b7e6506c703?fccid=38afdc89b4d82c80&amp;vjs=3" id="jl_03681b7e6506c703" onclick="setRefineByCookie([]); return rclk(this,jobmap[8],true,1);" onmousedown="return rclk(this,jobmap[8],1);" rel="noopener nofollow" target="_blank" title="Data Analyst">
# <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# Apex Limited,LLC</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_03681b7e6506c703" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA</span>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $70,000 - $85,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td><td class="jobCardShelfItem"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 16 16" width="16"><rect fill="#DB183F" height="16" rx="8" width="16"></rect><g clip-path="url(#clip0)"><path clip-rule="evenodd" d="M7.99515 3.20001C5.34555 3.20001 3.19995 5.35041 3.19995 8.00001C3.19995 10.6496 5.34555 12.8 7.99515 12.8C10.6496 12.8 12.8 10.6496 12.8 8.00001C12.8 5.35041 10.6496 3.20001 7.99515 3.20001ZM7.99995 11.84C5.87835 11.84 4.15995 10.1216 4.15995 8.00001C4.15995 5.87841 5.87835 4.16001 7.99995 4.16001C10.1216 4.16001 11.84 5.87841 11.84 8.00001C11.84 10.1216 10.1216 11.84 7.99995 11.84Z" fill="white" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M8.24002 5.60001H7.52002V8.48001L10.04 9.99201L10.4 9.40161L8.24002 8.12001V5.60001Z" fill="white" fill-rule="evenodd"></path></g><defs><clippath><rect fill="white" height="9.6" transform="translate(3.19995 3.20001)" width="9.6"></rect></clippath></defs></svg></span>Urgently hiring</td></tr></table><div class="summary">
# We are looking for a passionate certified Data Analyst. The successful candidate will turn data into information, information into insight and insight into…</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# ...
# Business <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# Essani International LLC</span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_b444422939c7c3f1" style="display: none"></div>
# <span class="location accessible-contrast-color-location">San Francisco, CA</span>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $45 - $50 an hour</span>
# </span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td></tr></table><div class="summary">
# Phone call followed by an interview*. Determines operational objectives by studying business functions; Evaluating output requirements and formats.</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="date">30+ days ago</span><span class="tt_set" id="tt_set_14"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_b444422939c7c3f1" onclick="changeJobState('b444422939c7c3f1', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_14" onclick="toggleMoreLinks('b444422939c7c3f1'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_b444422939c7c3f1" style="display:none;"></div><script>if (!window['result_b444422939c7c3f1']) {window['result_b444422939c7c3f1'] = {};}window['result_b444422939c7c3f1']['showSource'] = false; window['result_b444422939c7c3f1']['source'] = "Indeed"; window['result_b444422939c7c3f1']['loggedIn'] = false; window['result_b444422939c7c3f1']['showMyJobsLinks'] = false;window['result_b444422939c7c3f1']['undoAction'] = "unsave";window['result_b444422939c7c3f1']['relativeJobAge'] = "30+ days ago";window['result_b444422939c7c3f1']['jobKey'] = "b444422939c7c3f1"; window['result_b444422939c7c3f1']['myIndeedAvailable'] = true; window['result_b444422939c7c3f1']['showMoreActionsLink'] = window['result_b444422939c7c3f1']['showMoreActionsLink'] || true; window['result_b444422939c7c3f1']['resultNumber'] = 14; window['result_b444422939c7c3f1']['jobStateChangedToSaved'] = false; window['result_b444422939c7c3f1']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['result_b444422939c7c3f1']['basicPermaLink'] = "https://www.indeed.com"; window['result_b444422939c7c3f1']['saveJobFailed'] = false; window['result_b444422939c7c3f1']['removeJobFailed'] = false; window['result_b444422939c7c3f1']['requestPending'] = false; window['result_b444422939c7c3f1']['notesEnabled'] = true; window['result_b444422939c7c3f1']['currentPage'] = "serp"; window['result_b444422939c7c3f1']['sponsored'] = false;window['result_b444422939c7c3f1']['reportJobButtonEnabled'] = false; window['result_b444422939c7c3f1']['showMyJobsHired'] = false; window['result_b444422939c7c3f1']['showSaveForSponsored'] = false; window['result_b444422939c7c3f1']['showJobAge'] = true; window['result_b444422939c7c3f1']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="more-links-container result-tab" id="tt_display_9" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('b444422939c7c3f1'); return false;" title="Close"></a><div class="more_actions" id="more_9"><ul><li><span class="mat">View all <a href="/jobs?q=Essani+International+LLC&amp;l=San+Francisco,+CA&amp;nc=jasx">Essani International LLC jobs in San Francisco, CA</a> - <a href="/l-San-Francisco,-CA-jobs.html">San Francisco jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-San-Francisco-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=b444422939c7c3f1&amp;from=serp-more');">Data Analyst salaries in San Francisco, CA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Essani-International-1" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=b444422939c7c3f1&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=43d0bd6d59155d9a');">Essani International LLC</a></span></li><li><span class="mat">Related forums: <a href="/forum/cmp/Essani-International-1.html">Essani International</a> - <a href="/forum/job/Business-Data-Analyst.html">Business Data Analyst</a> - <a href="/forum/loc/SAN-Francisco-California.html">SAN Francisco, California</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# <div class="sign-in-container result-tab"></div>
# <div class="notes-container result-tab"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="316371642" data-empn="3662171322570313" data-jk="e227f2271c5f4381" id="pj_e227f2271c5f4381">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ANu1nuBOk5R0FA0HVqE7hblX8Sd9pCnUK5JC4tLNKrcYCfOnF0inVXpJq71XU6XQdfAUsU7LW8cmQ8FcC1TbCIvX2o0w4ktn4jjZo1yUhO9GKWH4rTFv1sH1Pt4XPR6hjqntCXjhcYgOI9Rkc0QOWwFEf_lQfpBBDm6iGUVqhH2nW4kKYW2DlME5ExWc11URKYdcwcWQMKBOX22Ns-GtpbiaZF93kofGFuhLrY5hoUdAvBN23zi7KDi7A4MzEqzQKE8L4L45gaPvumOrL22nMSwZnXw7OHuMoL-qnPd_jS-EmQFL8C_j4pp4RPLknIKkIFRIBL4bajy1SIqTyYJ4rCEpooIBrtlXRId4_2wjXhxzL6N7-0dAMHGkqdh1NpxIc4DDFcHAomoFpBzKGNISG87BGMo4EnIPbvuFviZHlMhN5Mass9-orJ&amp;p=15&amp;fvj=1&amp;vjs=3" id="sja15" onclick="setRefineByCookie([]); sjoc('sja15', 1); convCtr('SJ')" onmousedown="sjomd('sja15'); clk('sja15');" rel="noopener nofollow" target="_blank" title="Data Analyst">
# <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# CMBS.com</span>
# </div>
# <div class="recJobLoc" data-rc-loc="Sausalito, CA" id="recJobLoc_e227f2271c5f4381" style="display: none"></div>
# <div class="location accessible-contrast-color-location">Sausalito, CA 94965</div>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $15 - $25 an hour</span>
# </span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td></tr></table><div class="summary">
# CMBS.com is a Commercial Real Estate Software Company in the midst of an exciting growth period. The individual will become familiar with CMBS securitizations…</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_15"><a class="sl resultLink save-job-link" href="#" id="sj_e227f2271c5f4381" onclick="changeJobState('e227f2271c5f4381', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_e227f2271c5f4381" style="display:none;"></div><script>if (!window['sj_result_e227f2271c5f4381']) {window['sj_result_e227f2271c5f4381'] = {};}window['sj_result_e227f2271c5f4381']['showSource'] = false; window['sj_result_e227f2271c5f4381']['source'] = "Indeed"; window['sj_result_e227f2271c5f4381']['loggedIn'] = false; window['sj_result_e227f2271c5f4381']['showMyJobsLinks'] = false;window['sj_result_e227f2271c5f4381']['undoAction'] = "unsave";window['sj_result_e227f2271c5f4381']['jobKey'] = "e227f2271c5f4381"; window['sj_result_e227f2271c5f4381']['myIndeedAvailable'] = true; window['sj_result_e227f2271c5f4381']['showMoreActionsLink'] = window['sj_result_e227f2271c5f4381']['showMoreActionsLink'] || false; window['sj_result_e227f2271c5f4381']['resultNumber'] = 15; window['sj_result_e227f2271c5f4381']['jobStateChangedToSaved'] = false; window['sj_result_e227f2271c5f4381']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_e227f2271c5f4381']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_e227f2271c5f4381']['saveJobFailed'] = false; window['sj_result_e227f2271c5f4381']['removeJobFailed'] = false; window['sj_result_e227f2271c5f4381']['requestPending'] = false; window['sj_result_e227f2271c5f4381']['notesEnabled'] = false; window['sj_result_e227f2271c5f4381']['currentPage'] = "serp"; window['sj_result_e227f2271c5f4381']['sponsored'] = true;window['sj_result_e227f2271c5f4381']['showSponsor'] = true;window['sj_result_e227f2271c5f4381']['reportJobButtonEnabled'] = false; window['sj_result_e227f2271c5f4381']['showMyJobsHired'] = false; window['sj_result_e227f2271c5f4381']['showSaveForSponsored'] = true; window['sj_result_e227f2271c5f4381']['showJobAge'] = true; window['sj_result_e227f2271c5f4381']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>, <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="318379110" data-empn="5801936766424376" data-jk="080d7c049d19e209" id="pj_080d7c049d19e209">
# <div class="title">
# <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BzOad_ffvZ6joMfjW5V8SWZ38-9tCzRrNihK7d5ZGG97lWmtAcFbZmIVLTkMTL04C95qP1tWYH8eL88sU3IEnHVWQWBQeUb4f6JR6GOAoUxcSMVLNwjW5xDtMNbUjoUSgL6LKJK-EFCYqMBiHvgl6s4VsvQ2T54R_za8Qnx6mFvEJv-12b71H0YTFsXPq93tRe7KmhmNL6h_lMoJkzaa4DLN4R7Di16OWMHI7Pd4TFEAJdCXx3AOXmc-qNqAv31NzHGnFaozDPqtBEUGBbMDzCc5jke29eh55hZR7bpSOOgp8DSzlf-M6-AH5-aPHG8CUNUaN4PwMmLn3634NKg4C5RoNrtiPhXRTxL2h5QqTd6stoisz8OnP0EX7kzA7QFhQNSDgjBOfJlCrDziAMqobZCYNYWuUh-M7sipWINzdkvH13DYFu9aeR&amp;p=16&amp;fvj=1&amp;vjs=3" id="sja16" onclick="setRefineByCookie([]); sjoc('sja16', 1); convCtr('SJ')" onmousedown="sjomd('sja16'); clk('sja16');" rel="noopener nofollow" target="_blank" title="Data Analyst">
# <b>Data</b> <b>Analyst</b></a>
# </div>
# <div class="sjcl">
# <div>
# <span class="company">
# <a class="turnstileLink" data-tn-element="companyName" href="/cmp/SAN-Francisco-Community-Clinic-Consortium" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=080d7c049d19e209&amp;jcid=fabf7bd9f228e9da')" rel="noopener" target="_blank">
# SAN FRANCISCO COMMUNITY CLINIC CONSORTIUM</a></span>
# <span class="ratingsDisplay">
# <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/SAN-Francisco-Community-Clinic-Consortium/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Analyst&amp;fromjk=080d7c049d19e209&amp;jcid=fabf7bd9f228e9da');" rel="noopener" target="_blank">
# <span class="ratingsContent">
# 3.7<svg class="starIcon" height="12px" role="img" width="12px">
# <g>
# <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
# </g>
# </svg>
# </span>
# </a>
# </span>
# </div>
# <div class="recJobLoc" data-rc-loc="San Francisco, CA" id="recJobLoc_080d7c049d19e209" style="display: none"></div>
# <div class="location accessible-contrast-color-location">San Francisco, CA 94133 <span style="font-size: smaller">(Russian Hill area)</span></div>
# </div>
# <div class="salarySnippet holisticSalary">
# <span class="salary no-wrap">
# <span class="salaryText">
# $50,000 - $55,000 a year</span>
# </span>
# </div>
# <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply</span></td><td class="jobCardShelfItem"><span class="jobCardShelfIcon"><svg fill="none" height="16" viewbox="0 0 16 16" width="16"><rect fill="#DB183F" height="16" rx="8" width="16"></rect><g clip-path="url(#clip0)"><path clip-rule="evenodd" d="M7.99515 3.20001C5.34555 3.20001 3.19995 5.35041 3.19995 8.00001C3.19995 10.6496 5.34555 12.8 7.99515 12.8C10.6496 12.8 12.8 10.6496 12.8 8.00001C12.8 5.35041 10.6496 3.20001 7.99515 3.20001ZM7.99995 11.84C5.87835 11.84 4.15995 10.1216 4.15995 8.00001C4.15995 5.87841 5.87835 4.16001 7.99995 4.16001C10.1216 4.16001 11.84 5.87841 11.84 8.00001C11.84 10.1216 10.1216 11.84 7.99995 11.84Z" fill="white" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M8.24002 5.60001H7.52002V8.48001L10.04 9.99201L10.4 9.40161L8.24002 8.12001V5.60001Z" fill="white" fill-rule="evenodd"></path></g><defs><clippath><rect fill="white" height="9.6" transform="translate(3.19995 3.20001)" width="9.6"></rect></clippath></defs></svg></span>Urgently hiring</td></tr></table><div class="summary">
# San Francisco Community Clinic Consortium (SFCCC) develops innovative programs and advocates for policies to increase access to quality community-based primary…</div>
# <div class="jobsearch-SerpJobCard-footer">
# <div class="jobsearch-SerpJobCard-footerActions">
# <div class="result-link-bar-container">
# <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="tt_set" id="tt_set_16"><a class="sl resultLink save-job-link" href="#" id="sj_080d7c049d19e209" onclick="changeJobState('080d7c049d19e209', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_080d7c049d19e209" style="display:none;"></div><script>if (!window['sj_result_080d7c049d19e209']) {window['sj_result_080d7c049d19e209'] = {};}window['sj_result_080d7c049d19e209']['showSource'] = false; window['sj_result_080d7c049d19e209']['source'] = "Indeed"; window['sj_result_080d7c049d19e209']['loggedIn'] = false; window['sj_result_080d7c049d19e209']['showMyJobsLinks'] = false;window['sj_result_080d7c049d19e209']['undoAction'] = "unsave";window['sj_result_080d7c049d19e209']['jobKey'] = "080d7c049d19e209"; window['sj_result_080d7c049d19e209']['myIndeedAvailable'] = true; window['sj_result_080d7c049d19e209']['showMoreActionsLink'] = window['sj_result_080d7c049d19e209']['showMoreActionsLink'] || false; window['sj_result_080d7c049d19e209']['resultNumber'] = 16; window['sj_result_080d7c049d19e209']['jobStateChangedToSaved'] = false; window['sj_result_080d7c049d19e209']['searchState'] = "q=data analyst&amp;l=San+Francisco%2C+CA"; window['sj_result_080d7c049d19e209']['basicPermaLink'] = "https://www.indeed.com"; window['sj_result_080d7c049d19e209']['saveJobFailed'] = false; window['sj_result_080d7c049d19e209']['removeJobFailed'] = false; window['sj_result_080d7c049d19e209']['requestPending'] = false; window['sj_result_080d7c049d19e209']['notesEnabled'] = false; window['sj_result_080d7c049d19e209']['currentPage'] = "serp"; window['sj_result_080d7c049d19e209']['sponsored'] = true;window['sj_result_080d7c049d19e209']['showSponsor'] = true;window['sj_result_080d7c049d19e209']['reportJobButtonEnabled'] = false; window['sj_result_080d7c049d19e209']['showMyJobsHired'] = false; window['sj_result_080d7c049d19e209']['showSaveForSponsored'] = true; window['sj_result_080d7c049d19e209']['showJobAge'] = true; window['sj_result_080d7c049d19e209']['showHolisticCard'] = true;</script></div></div>
# </div>
# </div>
# <div class="tab-container">
# <div class="sign-in-container result-tab"></div>
# <div class="tellafriend-container result-tab email_job_content"></div>
# </div>
# </div>]

# %%
data = []
for row in job_vacancy:
    #Error handling
    try:
        print("---------")
        # Scrape the job-title
        job_title = row.find("div", class_= "title")
        if job_title:  
            job_title = job_title.text.strip()
        else:
            job_title = "No job_title"
        
        # Scrape the company
        company_name = row.find("span", class_= "company")
        if company_name:  
            company_name = company_name.text.strip()
        else:
            company_name = "No Company Name"
    
        print(company_name)
        # Scrape the location
        location = row.find("div", class_="location")
        if location:  
            location = location.text.strip()
        else:
            location = "No Location"
        print(location)
    
        # Scrape the salary
        salary = row.find("span", class_="no-wrap")
        if salary:  
            salary = salary.text.strip()
        else:
            salary = "No Salary"
        print(salary)
    
        # Scrape the summary
        summary = row.find("div", class_="summary")
        if (summary):
            summary = summary.text.strip()
        else:
            summary = "No Summary"
        print(summary)
    
        # Scrape the ratings
        rating = row.find("span", class_="ratingsContent")
        if rating:
            rating = rating.text.strip()
        else:
            rating = "No rating"
        print(rating)
    
        # Check if the data is available
        if (job_title and location and salary and summary and rating):
        
            job_dic = {
                "title": job_title,
                "company": company_name,
                "location": location,
                "salary": salary,
                "summary": summary,
                "rating": rating
        
            }
#             print(job_dic)
        data.append(job_dic)
        
#         "collection.insert_one(job_dic)"
    except Exception as e:
        print(e)
        
print(data)
df = pd.DataFrame(data)
df.head()
# Out:
# ---------
# HubHaus
# San Francisco, CA
# No Salary
# We are a small, fast growing startup in the co-living space that is expanding rapidly. We'll continue our rapid expansion over the next year as we push into new…
# 3.0
# ---------
# Lyft
# San Francisco, CA
# No Salary
# Extremely detail oriented and highly organized. At Lyft, community is what we are and it's what we do. It's what makes us different.
# 3.5
# ---------
# Aaratechinc
# San Francisco, CA
# $55,000 - $70,000 a year
# Must have CUSTOMER FACING Experience. Bachelor's Degree in appropriate field of study or equivalent work experience.
# No rating
# ---------
# Seen by Indeed
# San Francisco, CA
# No Salary
# Seen by Indeed is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles.
# No rating
# ---------
# Tanko Lighting
# San Francisco, CA 94124 (Bayview area)
# No Salary
# Tanko Lighting is looking for a rock star. Our professional services team needs someone who can tackle massive amounts of data one day, then turn around and…
# 3.4
# ---------
# MINTED LLC
# No Location
# No Salary
# Obsessive attention to detail with a knack for pattern recognition. Manage and maintain production database and other environments used for testing.
# 3.9
# ---------
# InfoObjects Inc
# No Location
# No Salary
# Manually going through sales files. Come in and build out certain macros. Automate some of the workflow. 1 year xp with macros, doesn't really care how much xp.
# No rating
# ---------
# Minted
# No Location
# No Salary
# Support Engineering with data needs, debugging, testing, tools, and automation. Support Merchandising and execute product data audits.
# 3.9
# ---------
# Apex Limited,LLC
# No Location
# $70,000 - $85,000 a year
# We are looking for a passionate certified Data Analyst. The successful candidate will turn data into information, information into insight and insight into…
# No rating
# ---------
# Trajectory HR Solutions
# No Location
# $130,000 a year
# US$ 90,000 to 130,000 depending on qualifications. H1-B, H4, F-1 (OPT) or any other visa status will not be considered as client will not sponsor current or…
# No rating
# ---------
# University of California San Francisco
# No Location
# No Salary
# The Data Analyst works on research data reporting assignments that are of moderate diversity in scope. Exercises judgment within generally defined practices and…
# 4.2
# ---------
# University of California San Francisco
# No Location
# No Salary
# Understanding and implementing relevant, evidence-based psychosocial rehabilitation and psychopharmacological treatments, 2) promoting recovery, and 3)…
# 4.2
# ---------
# University of California San Francisco
# No Location
# No Salary
# The Data Systems Analyst applies skills as a seasoned, experienced data / information management professional with full understanding of industry practices and…
# 4.2
# ---------
# Kaiser Permanente
# No Location
# No Salary
# This position functions both as an analyst and as a statistical analytics programmer. Designs menu systems that are effective and user-friendly.
# 4.2
# ---------
# Essani International LLC
# No Location
# $45 - $50 an hour
# Phone call followed by an interview*. Determines operational objectives by studying business functions; Evaluating output requirements and formats.
# No rating
# ---------
# CMBS.com
# Sausalito, CA 94965
# $15 - $25 an hour
# CMBS.com is a Commercial Real Estate Software Company in the midst of an exciting growth period. The individual will become familiar with CMBS securitizations…
# No rating
# ---------
# SAN FRANCISCO COMMUNITY CLINIC CONSORTIUM
# San Francisco, CA 94133 (Russian Hill area)
# $50,000 - $55,000 a year
# San Francisco Community Clinic Consortium (SFCCC) develops innovative programs and advocates for policies to increase access to quality community-based primary…
# 3.7
# [{'title': 'Growth Data Analyst', 'company': 'HubHaus', 'location': 'San Francisco, CA', 'salary': 'No Salary', 'summary': "We are a small, fast growing startup in the co-living space that is expanding rapidly. We'll continue our rapid expansion over the next year as we push into new…", 'rating': '3.0'}, {'title': 'Financial Data Analyst, Tax', 'company': 'Lyft', 'location': 'San Francisco, CA', 'salary': 'No Salary', 'summary': "Extremely detail oriented and highly organized. At Lyft, community is what we are and it's what we do. It's what makes us different.", 'rating': '3.5'}, {'title': 'Business Analyst', 'company': 'Aaratechinc', 'location': 'San Francisco, CA', 'salary': '$55,000 - $70,000 a year', 'summary': "Must have CUSTOMER FACING Experience. Bachelor's Degree in appropriate field of study or equivalent work experience.", 'rating': 'No rating'}, {'title': 'Data Analyst', 'company': 'Seen by Indeed', 'location': 'San Francisco, CA', 'salary': 'No Salary', 'summary': "Seen by Indeed is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles.", 'rating': 'No rating'}, {'title': 'GIS Data Analyst', 'company': 'Tanko Lighting', 'location': 'San Francisco, CA 94124 (Bayview area)', 'salary': 'No Salary', 'summary': 'Tanko Lighting is looking for a rock star. Our professional services team needs someone who can tackle massive amounts of data one day, then turn around and…', 'rating': '3.4'}, {'title': 'Associate Product Data Analyst', 'company': 'MINTED LLC', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Obsessive attention to detail with a knack for pattern recognition. Manage and maintain production database and other environments used for testing.', 'rating': '3.9'}, {'title': 'Data Analyst Part time (30 hrs Week) +1 Month', 'company': 'InfoObjects Inc', 'location': 'No Location', 'salary': 'No Salary', 'summary': "Manually going through sales files. Come in and build out certain macros. Automate some of the workflow. 1 year xp with macros, doesn't really care how much xp.", 'rating': 'No rating'}, {'title': 'Associate Product Data Analyst', 'company': 'Minted', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Support Engineering with data needs, debugging, testing, tools, and automation. Support Merchandising and execute product data audits.', 'rating': '3.9'}, {'title': 'Data Analyst', 'company': 'Apex Limited,LLC', 'location': 'No Location', 'salary': '$70,000 - $85,000 a year', 'summary': 'We are looking for a passionate certified Data Analyst. The successful candidate will turn data into information, information into insight and insight into…', 'rating': 'No rating'}, {'title': 'Data Analyst', 'company': 'Trajectory HR Solutions', 'location': 'No Location', 'salary': '$130,000 a year', 'summary': 'US$ 90,000 to 130,000 depending on qualifications. H1-B, H4, F-1 (OPT) or any other visa status will not be considered as client will not sponsor current or…', 'rating': 'No rating'}, {'title': 'Data Analyst', 'company': 'University of California San Francisco', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'The Data Analyst works on research data reporting assignments that are of moderate diversity in scope. Exercises judgment within generally defined practices and…', 'rating': '4.2'}, {'title': 'Research Data Analyst 1', 'company': 'University of California San Francisco', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Understanding and implementing relevant, evidence-based psychosocial rehabilitation and psychopharmacological treatments, 2) promoting recovery, and 3)…', 'rating': '4.2'}, {'title': 'Data Systems Analyst', 'company': 'University of California San Francisco', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'The Data Systems Analyst applies skills as a seasoned, experienced data / information management professional with full understanding of industry practices and…', 'rating': '4.2'}, {'tit ...
#           company                                location     rating  \
# 0         HubHaus                       San Francisco, CA        3.0
# 1            Lyft                       San Francisco, CA        3.5
# 2     Aaratechinc                       San Francisco, CA  No rating
# 3  Seen by Indeed                       San Francisco, CA  No rating
# 4  Tanko Lighting  San Francisco, CA 94124 (Bayview area)        3.4
#
#                      salary  \
# 0                 No Salary
# 1                 No Salary
# 2  $55,000 - $70,000 a year
# 3                 No Salary
# 4                 No Salary
#
#                                              summary  \
# 0  We are a small, fast growing startup in the co...
# 1  Extremely detail oriented and highly organized...
# 2  Must have CUSTOMER FACING Experience. Bachelor...
# 3  Seen by Indeed is a free service that connects...
# 4  Tanko Lighting is looking for a rock star. Our...
#
#                          title
# 0          Growth Data Analyst
# 1  Financial Data Analyst, Tax
# 2             Business Analyst
# 3                 Data Analyst
# 4             GIS Data Analyst

# %%
max_results_per_city = 100
city_list = ["New+York","Chicago","San+Francisco", "Austin", "Seattle", "Los+Angeles", "Philadelphia", "Atlanta",
            "Dallas", "Pittsburgh", "Portland", "Phoenix", "Denver", "Houston", "Miami", "Raleigh", "Washington+DC", "Boulder"]
columns = ["company", "location", "rating", "salary", "summary", "title"]
sample_df = pd.DataFrame(columns = columns)

# %%
# Loop to visit each page in a specific order to extract the data we need
all_data = []
for city in city_list:
    for start in range(0, max_results_per_city, 10):
        url = "https://www.indeed.com/jobs?q=data+analyst&l=" + str(city) + "&start=" + str(start)
        print(url)
        page = requests.get(url)
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text,"html.parser")
        job_vacancy = soup.find_all(name="div", attrs={"class":"jobsearch-SerpJobCard"})
        for row in job_vacancy:
            #Error handling
            try:
                print("---------")
                # Scrape the job-title
                job_title = row.find("div", class_= "title")
                if job_title:  
                    job_title = job_title.text.strip()
                else:
                    job_title = "No job_title"
        
                # Scrape the company
                company_name = row.find("span", class_= "company")
                if company_name:  
                    company_name = company_name.text.strip()
                else:
                    company_name = "No Company Name"
    
                print(company_name)
                # Scrape the location
                location = row.find("div", class_="location")
                if location:  
                    location = location.text.strip()
                else:
                    location = "No Location"
                print(location)
    
                # Scrape the salary
                salary = row.find("span", class_="no-wrap")
                if salary:  
                    salary = salary.text.strip()
                else:
                    salary = "No Salary"
                print(salary)
    
                # Scrape the summary
                summary = row.find("div", class_="summary")
                if (summary):
                    summary = summary.text.strip()
                else:
                    summary = "No Summary"
                print(summary)
    
                # Scrape the ratings
                rating = row.find("span", class_="ratingsContent")
                if rating:
                    rating = rating.text.strip()
                else:
                    rating = "No rating"
                print(rating)
    
                # Check if the data is available
                if (job_title and location and salary and summary and rating):
        
                    job_dic = {
                        "title": job_title,
                        "company": company_name,
                        "location": location,
                        "salary": salary,
                        "summary": summary,
                        "rating": rating
        
                    }
                all_data.append(job_dic)
#         "collection.insert_one(job_dic)"
            except Exception as e:
                print(e)
            
        
print(all_data)
all_df = pd.DataFrame(all_data)
all_df.head()
# Out:
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=0
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY.With impressive investors and a collaborative and winning team.There's an app for that" - USA Today.
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 4.8
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…
# 3.6
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# At Noom, we use scientifically proven methods to help our users create healthier lifestyles, and manage important conditions like Type-II Diabetes, Obesity, and…
# 3.9
# ---------
# KGS Technology Group, Inc.
# No Location
# $50,000 - $55,000 a year
# Interpret data, analyze results using statistical techniques and provide ongoing reports.Develop and implement databases, data collection systems, data…
# 4.5
# ---------
# KGS Technology Group, Inc
# No Location
# $50,000 - $60,000 a year
# _KGS Technology Group is one of the fast growing companies in IT consulting for fortune 500 clients.We cater to the application development and support…
# 4.5
# ---------
# Cedar Inc
# No Location
# No Salary
# Cedar is a patient payment and engagement platform that elevates the total patient experience beyond clinical care.Experience with query languages (e.g.
# 3.5
# ---------
# Medly Pharmacy
# No Location
# $20 - $25 an hour
# We’re looking for an entry-level data analyst who can turn data from multiple sources into our custom-formatted data reports.
# 3.3
# ---------
# Montefiore Medical Center
# No Location
# No Salary
# Creates, generates and analyzes statistical reports to track and measure various clinical functions.Troubleshoots hardware and software problems, maintains…
# 4.1
# ---------
# CloudServiceTek
# No Location
# $60,000 - $70,000 a year
# CloudServiceTek is hiring multiple Business Analysts.You will be part of a collaborative Agile team and will Analyze, Review and Document requirements for new…
# No rating
# ---------
# The New York Times
# No Location
# No Salary
# Seeking analytical talent to turn passion for data and support of world-class journalism into tools and insights.It is also the smart thing for our business.
# 4.0
# ---------
# RedRoute
# No Location
# $65,000 - $95,000 a year
# RedRoute is paving the path to amazing voice-enabled interactions with technology.Alexa) is a growing field and our advancements across voice UI & voice…
# No rating
# ---------
# Integrated Reporting is Simple (IRIS CRM)
# No Location
# $55,000 - $70,000 a year
# On a scale of 1 to 5, with 5 being expert, how would you rate your Excel skills?COMPANY WEBSITE | CRUNCHBASE | CEO | HIRING MANAGER*.
# No rating
# ---------
# Quantbot Technologies LP
# No Location
# No Salary
# A global finance company is looking for an Entry-level Intern in a Junior Data Developer/Analyst role to join their Core Data team.
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# 3.5
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# Horizon Health Services is a not-for-profit corporation in Western New York that provides hope and healing for individuals and their families dealing with…
# 3.1
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=10
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# No rating
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.Data Analyst: 2 years (Required).
# No rating
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Data Analyst: 5 years (Required).Must be a critical thinker and problem-solvercapable of strict attention to detail; must have superior organization and…
# No rating
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# Understanding appropriate regulatory initiatives impacting Global Banking.Supporting Global Banking Data initiatives and Future State architecture program.
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# We are looking for a Sr. Data Analyst to join our Data team and help us perform complex analysis and modelling on our data warehouse.
# No rating
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Bertelsmann, Inc.
# No Location
# No Salary
# As a Data Science Intern in the newly formed New York-based “Data Lab” of the Bertelsmann Education Group (BEG), you will be working on the forefront of the…
# No rating
# ---------
# Comcast
# No Location
# No Salary
# This data analyst will work with our Product and Engineering teams to inform product and feature strategies.Write software to analyze large data sets.
# No rating
# ---------
# 3x3 Insights
# No Location
# $15 - $25 an hour
# Data Mapping Analyst – Part Time.3x3 Insights Data Mapping Analyst.Job Overview:  The 3x3 Insights Data Mapping Team is the foundation of our business.
# No rating
# ---------
# LJM Group
# No Location
# No Salary
# We are a B2B Consulting Firm within the Logistics industry seeking a business-minded individual with exceptional data analysis skills and aptitude.
# No rating
# ---------
# NYC Health + Hospitals
# No Location
# No Salary
# The IT Core Systems Data Quality Analyst (DQA) develops and submits provider-focused regulatory and ad hoc reports.Strong knowledge of MS SQL.
# No rating
# ---------
# RedRoute
# No Location
# $65,000 - $95,000 a year
# We focus on communication between individuals and businesses.We're looking for a lead data analyst to join our 14-person product & engineering team.
# No rating
# ---------
# ICC Logistics Services
# No Location
# No Salary
# Must be able to assess the quality and accuracy of specific data elements.Must be able to relate the data to the client so that proper business decisions can…
# No rating
# ---------
# Quantbot Technologies LP
# No Location
# No Salary
# This is a great opportunity for a passionate technologist candidate who loves problem-solving in a production environment and enjoys using data science…
# No rating
# ---------
# Salesforce
# No Location
# No Salary
# We offer job shadowing, mentorship programs, talent development courses, and much more.Title: Winter 2020 Co-op - Data and Automation Analyst.
# No rating
# ---------
# Comcast
# No Location
# No Salary
# The department is responsible for developing software components for FreeWheel's advertising platform products and working closely with FreeWheel's Client Team…
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Subject matter expert in our data capabilities and the value proposition of our data partners.Subject matter expert in our targeting and reporting…
# No rating
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# Reporting to the VP of Finance, the candidate will help build an infrastructure which will support future growth."33 Startups to watch" - Business Insider.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=20
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.Data Analyst: 2 years (Required).
# 2.5
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# 3.1
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 4.8
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Addressable campaign data and attribution support for Advanced Advertising Sales team.Subject matter expert in our data capabilities and the value proposition…
# 3.5
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…
# 3.6
# ---------
# US Department of Housing and Urban Development
# No Location
# $71,593 - $111,558 a year
# 3 full years of progressively higher level graduate education leading to such a degree.This opportunity is also open to Status eligibles under Announcement 19…
# 4.1
# ---------
# Fragomen
# No Location
# No Salary
# Our NY office seeks a dynamic full time Immigration Data Analyst with 1-2 years of experience whose primary responsibility will be to provide reporting support…
# 3.2
# ---------
# Bertelsmann, Inc.
# No Location
# No Salary
# As part of the Data Lab, you will have the opportunity to work directly with high-level executives of companies such as Udacity, Relias, HotChalk, and Alliant…
# 3.7
# ---------
# Aramark
# No Location
# No Salary
# This role will primarily be that of a Data Analyst with a supporting role of providing general office support for our Albany, NY office.
# 3.6
# ---------
# Yewno
# No Location
# No Salary
# An innovative platform that provides insights and answers to the complexity.We are an accomplished team of alums from top.
# No rating
# ---------
# MetroPlus Health Plan
# No Location
# $80,000 - $85,000 a year
# The IT Core Systems Data Quality Analyst (DQA) develops and submits provider-focused regulatory and ad hoc reports.Strong knowledge of MS SQL.
# 3.1
# ---------
# Viacom
# No Location
# No Salary
# Advertising is being reinvented through big data, audience segmentation tools, digital platforms and formats as well as new consumer consumption patterns.
# 4.1
# ---------
# CloudServiceTek
# No Location
# $60,000 - $70,000 a year
# You will be part of a collaborative Agile team and will Analyze, Review and Document requirements for new functionality requests and production issues.
# No rating
# ---------
# Neuberger Berman
# No Location
# No Salary
# 2 to 5 years of experience.Database Analyst - Consultant Data Team.Serve as primary data contact for Relationship Managers on key Consultant relationships.
# 3.9
# ---------
# American Express
# No Location
# No Salary
# The Merchant Experience team, within GS&C, leads the merchant Net Promoter System (NPS) program, which drives and measures merchant satisfaction across 15…
# 4.1
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Workwith team members to prioritize tasks and ensure that assigned projects arecompleted on schedule; organize, coordinate andimplement tasks with strong…
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# At least 4+ years of experience in a business intelligence of data analysis capacity, with a focus in data extraction, interpretation, and reporting.
# 3.9
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# They are seeking an experienced analyst to join their team in the position of Financial *Analyst.Reporting to the VP of Finance, the candidate will help…
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=30
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# Noom Inc.
# New York, NY
# No Salary
# We are looking for a Sr. Data Analyst to join our Data team and help us perform complex analysis and modelling on our data warehouse.
# 3.9
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# 3.1
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 4.8
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# 3.5
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank. Understanding appropriate regulatory initiatives impacting…
# 3.6
# ---------
# RedRoute
# No Location
# $65,000 - $95,000 a year
# We focus on communication between individuals and businesses. Our core product is RedRoute IVR (Interactive Voice Response), a Phone Call Automation System…
# No rating
# ---------
# Staffing Solutions Organization LLC (SSO)
# No Location
# No Salary
# Data Analyst (Medicaid Rate Setting) in Albany, NY. As a Data Analyst, part of the Medicaid rate setting team, you will be part of setting reimbursement rates…
# No rating
# ---------
# Oneida ESC Group
# No Location
# No Salary
# Our family of companies include: SRS has an immediate opening for a Data Analyst the United States Military Academy, West Point.
# No rating
# ---------
# SBH Health System
# No Location
# No Salary
# SBH Health System seeks a Clinical Data Analyst for Healthcare Analytics and Reporting. Clinical Data Analyst coordinates the valuation, design, testing,…
# 3.4
# ---------
# The New York Times
# No Location
# No Salary
# We then monetize these guides by enabling our users to easily purchase the products they are interested in. Who we are looking for:
# 4.0
# ---------
# Insero & Co CPAs LLP
# No Location
# No Salary
# Data Analytics Project Internship (Spring or Summer 2020). For the eight-straight year, Insero & Co. Our clients include individuals, government and not-for…
# No rating
# ---------
# Northern Westchester Hospital
# No Location
# No Salary
# Analyzes, implement and maintain department related databases and software. Serves as a liaison between department’s analytical needs and technical data storage…
# 3.9
# ---------
# Regeneron
# No Location
# No Salary
# Known for its scientific and operational excellence, Regeneron is a leading science-based biopharmaceutical company that discovers, invents, develops,…
# 3.8
# ---------
# Turner
# No Location
# No Salary
# We have multiple openings at Mid to Sr. See what it’s like to work at Turner! The Revenue Analytics team developed a Data Warehouse and Business Intelligence…
# 4.0
# ---------
# Northwell Health
# No Location
# No Salary
# As the Data Research Analyst, you will coordinate and maintain the clinical databases. You will collect, input, analyze and report data.
# 4.0
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Organize, coordinate andimplement tasks with strong attention to detail. Must be a critical thinker and problem-solvercapable of strict attention to detail;
# No rating
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY. They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=40
# ---------
# Montefiore Medical Center
# No Location
# No Salary
# Creates, generates and analyzes statistical reports to track and measure various clinical functions.Troubleshoots hardware and software problems, maintains…
# No rating
# ---------
# New York District Attorney's Office
# No Location
# No Salary
# The New York County District Attorney's Office (DANY) has an immediate opening for a Data Analyst in the Strategic Planning and Policy Unit.
# No rating
# ---------
# New York City DEPARTMENT OF TRANSPORTATION
# No Location
# $58,152 - $74,479 a year
# Detail oriented, and be able to perform well under pressure.*IN ORDER TO BE CONSIDERED FOR THIS POSITION, THE CANDIDATE MUST BE SERVING PERMANENTLY IN THE…
# No rating
# ---------
# Trumid
# No Location
# No Salary
# Drop us a line at careers@trumid.com.Trumid Labs is the quantitative analytics and data science group within Trumid.
# No rating
# ---------
# Facebook
# No Location
# No Salary
# Demonstrate initiative and strong attention to detail.The ideal candidate will have a strong technical, analytical, and solutions oriented mindset.
# No rating
# ---------
# States Title Holding
# No Location
# No Salary
# Every mortgage or refinance transaction needs our product:Title insurance protects banks and homeowners against financially irresponsible actors or legal…
# No rating
# ---------
# Mount Sinai
# No Location
# No Salary
# The Data Analyst II oversees activities related to data integrity, security and enhancement of the value of data.Work closely with IT management and staff.
# No rating
# ---------
# Facebook
# No Location
# No Salary
# This includes consultation with stakeholders, HR and other end users to create high value and intuitive dashboards, data visualizations and story-telling.
# No rating
# ---------
# Mindsgroup Infotech LLC
# No Location
# $60,000 - $80,000 a year
# O Fresher/ experience relevant technical or business work experience.O Strong problem solving and analytical skills.O Good sense of humor.
# No rating
# ---------
# Soft Inc.
# No Location
# No Salary
# 1 – 3 years previous work experience relating to research and analysis.Excellent written and verbal communication skills.
# No rating
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# No rating
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY.They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# Works under the Business Intelligence/Health Information Systems department to support the activities of direct the management, development, and integration of…
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=50
# ---------
# Google
# No Location
# No Salary
# 3 years of work experience in compensation consulting.Client-service oriented, with attention to detail and ability to prioritize competing demands.
# No rating
# ---------
# Northwell Health
# No Location
# No Salary
# As the Data Research Analyst, you will coordinate and maintain the clinical databases.You will collect, input, analyze and report data.
# No rating
# ---------
# FDM Group
# No Location
# No Salary
# Excellent attention to detail and strong organizational and time management abilities.We are currently seeking candidates interested in building a career in…
# No rating
# ---------
# Gallagher
# No Location
# No Salary
# Under general direction, provides support for one or more functional groups, including performance of a wide variety of specialized clerical functions involving…
# No rating
# ---------
# The Brooklyn Hospital Center
# No Location
# No Salary
# Implements AIRS (AIDS Institute Reporting System) within the two PATH Center programs funded under the contract with New York State Department of Health.
# No rating
# ---------
# Neuberger Berman
# No Location
# No Salary
# 2 to 5 years of experience.Database Analyst - Consultant Data Team.Serve as primary data contact for Relationship Managers on key Consultant relationships.
# No rating
# ---------
# Cloudburst Media
# No Location
# No Salary
# The Analyst’s primary role is to research and analyze information that contributes to the development of products and reports that improve the performance of…
# No rating
# ---------
# LOCKHEED MARTIN CORPORATION
# No Location
# No Salary
# Responsible for contribution to the update and maintenance of process documentation for items 1 through 3 above.
# No rating
# ---------
# Facebook
# No Location
# No Salary
# Demonstrate initiative and strong attention to detail.The Data Analyst is responsible for helping to ensure the efficiency of Facebook’s People Data,…
# No rating
# ---------
# Soft Inc.
# No Location
# No Salary
# 1 – 3 years previous work experience relating to research and analysis.In New York, NY looking for a Legal Data Analyst for a long term contract assignment.
# No rating
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# No rating
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY.They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=60
# ---------
# United Nations Development Programme (UNDP)
# No Location
# No Salary
# And the achievement of equality between women and men as partners and beneficiaries of development, human rights, humanitarian action and peace and security.
# 4.4
# ---------
# Horizon Health Services
# No Location
# No Salary
# The Data Analyst works within the Data Analytics department under the supervision of the Director of Data Analytics and Infrastructure to support the activities…
# 3.1
# ---------
# New York City TAXI & LIMOUSINE COMMISSION
# No Location
# $44,104 - $57,000 a year
# Semester credits on the basis that each 3 graduate semester credits may be substituted for 6 of the required undergraduate semester credits.
# 2.8
# ---------
# INEVITABLE ENTERPRISE's Client
# No Location
# $100,000 - $120,000 a year
# 5 years + experience working on multiple regulation focused projects such as;The successful candidate will have 5+ years as Business Analyst and will have:
# No rating
# ---------
# NATIONAL GRID CO USA (NE POWER)
# No Location
# No Salary
# Minimum 3 years of related finance/accounting/Operations work experience.National Grid is seeking a Lead Analyst for our Electric Project Manager position in…
# 3.8
# ---------
# GESTURE
# No Location
# No Salary
# Gesture is one of the newest on-demand companies to join the popular "on-demand" family.We are a fun, scrappy, yet organized tech start-up located in midtown.
# 4.8
# ---------
# Trumid
# No Location
# No Salary
# Drop us a line at careers@trumid.com.Trumid Labs is the quantitative analytics and data science group within Trumid.Beautiful location on Bryant Park in NYC.
# No rating
# ---------
# Neuberger Berman
# No Location
# No Salary
# 2 to 5 years of experience.Database Analyst - Consultant Data Team.Serve as primary data contact for Relationship Managers on key Consultant relationships.
# 3.9
# ---------
# KGS Technology Group, Inc
# No Location
# $50,000 - $60,000 a year
# Who is a data analyst?*.A data analyst collects and stores data on sales numbers, market research, logistics, linguistics, or other behaviors.
# 4.5
# ---------
# Bridging Access to Care, Inc
# No Location
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Organize, coordinate andimplement tasks with strong attention to detail.Must be a critical thinker and problem-solvercapable of strict attention to detail;
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# We are looking for a Sr.Data Analyst to join our Data team and help us perform complex analysis and modelling on our data warehouse.
# 3.9
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# 3.5
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…
# 3.6
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# 3.1
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 4.8
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY.They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=70
# ---------
# Gallagher
# No Location
# No Salary
# Gallagher is a global leader in insurance, risk management and consulting services. We help businesses grow, communities thrive and people prosper.
# 3.2
# ---------
# Bridging Access to Care, Inc
# No Location
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# SBH Health System
# No Location
# No Salary
# SBH Health System seeks a Clinical Data Analyst for Healthcare Analytics and Reporting. Clinical Data Analyst coordinates the valuation, design, testing,…
# 3.4
# ---------
# Mount Sinai
# No Location
# No Salary
# Prepares clear, well-organized project-specific documentation, including, at a minimum, analytic methods used, key decision points and caveats, with sufficient…
# 3.9
# ---------
# Cox Media Group
# No Location
# No Salary
# The Media Insights Analyst will perform data runs and analysis through the use of multiple syndicated research sources to support the media ad sales team and…
# 3.7
# ---------
# NYC IT
# No Location
# No Salary
# Business Analyst Analyzes an organization or business domain (real or hypothetical) and documents its business or processes or systems, assessing the business…
# No rating
# ---------
# IQVIA
# No Location
# No Salary
# IQVIA™ is the leading human data science company focused on helping healthcare clients find unparalleled insights and better solutions for patients.
# 3.9
# ---------
# VISITING NURSE SERVICE OF NEW YORK
# No Location
# No Salary
# Evaluates encounter data and identifies errors created by operational, claims and eligibility processes. Works closely with other departments, delegated vendors…
# 3.6
# ---------
# VISITING NURSE SERVICE OF NEW YORK
# No Location
# No Salary
# Compiles, analyzes, and reports on CHOICE health plan product data for the by leveraging relevant data to support strategic business decisions.
# 3.6
# ---------
# Citi
# No Location
# No Salary
# You're the brains behind our work. You're ready to bring your knowledge from the classroom to the boardroom; And Citi wants to help you get there.
# 3.9
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Organize, coordinate andimplement tasks with strong attention to detail. Must be a critical thinker and problem-solvercapable of strict attention to detail;
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# At Noom, we use scientifically proven methods to help our users create healthier lifestyles, and manage important conditions like Type-II Diabetes, Obesity, and…
# 3.9
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# 3.5
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank. Understanding appropriate regulatory initiatives impacting…
# 3.6
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# 2.5
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# Horizon Health Services is a not-for-profit corporation in Western New York that provides hope and healing for individuals and their families dealing with…
# 3.1
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 4.8
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY. With impressive investors and a collaborative and winning team. There's an app for that" - USA Today.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=80
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY. They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# ---------
# DoubleVerify
# No Location
# No Salary
# You are meticulous and detail oriented. We are currently seeking a Business Intelligence Analyst to work with our Product and Engineering teams to develop and…
# No rating
# ---------
# Rocketrip
# No Location
# No Salary
# We're looking for a Data Analyst to join our Data Analytics team. Our Data Analysts work collaboratively across multiple departments and act as a strategic…
# No rating
# ---------
# Acacia Technical Services
# No Location
# No Salary
# Highly self motivated, Keen attention to detail, Ability to effectively prioritize and execute tasks in a high pressure environment.
# No rating
# ---------
# PepsiCo
# No Location
# No Salary
# The Analyst, Data Science role is part of the forward-thinking Workforce Planning & Advanced Analytics Center-of-Excellence at PepsiCo's Headquarters in…
# No rating
# ---------
# NYSTEC
# No Location
# No Salary
# A minimum of a Bachelor's degree in a technical, scientific or related discipline with at least 3 years of relevant experience in the healthcare industry is…
# No rating
# ---------
# CertiK
# No Location
# No Salary
# Data Analyst will be responsible for collecting data from various sources and ensuring data integrity; Maintaining and managing current database;
# No rating
# ---------
# Guidepoint Global
# No Location
# No Salary
# Performing background research on various industries to help identify data partnerships in the healthcare industry.
# No rating
# ---------
# CVS Health
# No Location
# No Salary
# Aetna’s Analytics & Behavior Change team supports the entire organization by embedding deep analytic insights into key decision processes and focusing on our…
# No rating
# ---------
# Desh Technology Inc.
# No Location
# $65,000 - $85,000 a year
# Must be open to relocate based on projects. Salary increase up to 10% per year. We are seeking a Business Intelligence Analyst who will lead an analytics-driven…
# No rating
# ---------
# Digitas
# No Location
# No Salary
# The Data & Analysis team uses data-driven insights to fuel strategic growth for clients. As an Analyst, you’ll lay the groundwork and contribute to day-to-day…
# No rating
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank. Understanding appropriate regulatory initiatives impacting…
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
#  Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=New+York&start=90
# ---------
# S&P Global
# No Location
# No Salary
# Integrated quantamental research products enable portfolio managers, quantitative analysts, and researchers to refine and differentiate their strategies to gain…
# No rating
# ---------
# First Derivatives plc
# No Location
# No Salary
# We look for individuals who are strategic, thrive in a fast paced environment and possess a strong analytical aptitude to help solve complex business challenges…
# No rating
# ---------
# Montefiore Medical Center
# No Location
# No Salary
# AAS degree and a minimum 3 years payroll experience with payroll processes in use for fully automated systems are required. 8:30 AM-5 PM Req ID:
# No rating
# ---------
# St. Peter's Health Partners
# No Location
# No Salary
# Data management for multiple projects. Accessing and analyzing data sets to support quality improvement teams.
# No rating
# ---------
# Rao Strategic Solutions
# No Location
# $60,000 - $65,000 a year
# Students on OPT / CPT Welcome. Positions available in multiple locations across USA. We are looking for a Business Analyst who will be the vital link between…
# No rating
# ---------
# Apar Technologies
# No Location
# No Salary
# Good knowledge of Equity Products & Trade process such as Cash or OTC. Knowledge of ‘transaction reporting’ from business domain perspective not IT perspective.
# No rating
# ---------
# CenterLight Health System
# No Location
# No Salary
# The successful candidate will be detail and results oriented, problem solver by nature, and will possess strong organizational, analytical, communication and…
# No rating
# ---------
# Pinto
# No Location
# No Salary
# What you will be doing. You’ll work on our core data platform which processes large, complex data sets from a variety of sources.
# No rating
# ---------
# Refinitiv
# No Location
# No Salary
# Our Trading Platforms team needs a local Data Analyst to analyze, document, and catalog all ETI legacy data flows, as well as build the knowledge of data…
# No rating
# ---------
# sgsco
# No Location
# No Salary
# As a key figure within the process, you will help maintain and improve sgsco’s relationship with the Client. Respond in a timely manner to Clients.
# No rating
# ---------
# Alliant Cooperative Data Solutions
# Brewster, NY
# No Salary
# Organize, coordinate andimplement tasks with strong attention to detail. Must be a critical thinker and problem-solvercapable of strict attention to detail;
# No rating
# ---------
# Noom Inc.
# New York, NY
# No Salary
# We are looking for a Sr. Data Analyst to join our Data team and help us perform complex analysis and modelling on our data warehouse.
# No rating
# ---------
# Spectrum
# New York, NY 10012 (Little Italy area)
# No Salary
# Spectrum Reach (www.spectrumreach.com) grows businesses of all sizes with custom, multiscreen advertising solutions, backed by the power of TV, data, innovation…
# No rating
# ---------
# The Bachrach Group
# New York, NY 10001 (Chelsea area)
# $65 - $75 an hour
# 5 years or more of relevant data management, quality and governance experience with a tier 1 bank. Understanding appropriate regulatory initiatives impacting…
# No rating
# ---------
# Bridging Access to Care, Inc
# Brooklyn, NY
# $65,000 a year
# Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.
# No rating
# ---------
# Aaratechinc
# Manhattan, NY
# $55,000 - $70,000 a year
# Financial Services industry experience desired. Tableau , HTML, CSS, Splunk, Toad for MySQL, SQL Developer and Microsoft Office Suite products.
# No rating
# ---------
# Horizon Health Services
# Getzville, NY 14068
# No Salary
# The Data Analyst will work under the Business Intelligence and Health Information Systems department to support the activities of direct the management,…
# No rating
# ---------
# Fust Charles Chambers LLP
# Syracuse, NY 13214
# No Salary
# Fust Charles Chambers LLP, a premier accounting, tax and advisory services Firm in Central New York is seeking a Data Analyst that is looking to apply their…
# No rating
# ---------
# Plowz & Mowz Inc
# Syracuse, NY 13202 (Southwest area)
# No Salary
# PLOWZ & MOWZ, is a hot startup company in Syracuse, NY. They are seeking an experienced analyst to join their team in the position of Financial.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=Chicago&start=0
# ---------
# Aaratechinc
# Chicago, IL
# $55,000 - $70,000 a year
# Data Analysis, SQL, Date warehouse.Desired Skills "Basic Healthcare experience is preferred Good Knowledge on TSQL, PL/SQL.
# No rating
# ---------
# E*TRADE FINANCIAL
# Chicago, IL
# No Salary
# The role is part of the Data Insights & Initiatives team.You will join a team of ambitious and passionate associates, driven by ideas and with a bias towards…
# 3.6
# ---------
# United Airlines Inc.
# Chicago, IL 60601 (Loop area)
# No Salary
# Strong organization and project management skills, and strong attention to detail.This Digital Products and Analytics department consists of merchandising,…
# 4.0
# ---------
# American Board of Medical Specialties
# Chicago, IL 60601 (Loop area)
# No Salary
# The Data Analyst supports the needs of ABMS in aggregating, cleaning, and evaluating data from sources internal and external to ABMS.
# 4.0
# ---------
# Edge Systems LLC
# Du Page County, IL
# No Salary
# The analyst will be responsible for the execution of the IT Service Management (ITSM) processes in accordance with Edge adopted Incident, Problem, Change…
# No rating
# ---------
# Technosphere, Inc.
# Chicago, IL
# No Salary
# This position will be responsible for planning and organizing key Technology Vertical meetings and events and assist in operational data analysis activities and…
# No rating
# ---------
# The Art Institute of Chicago
# No Location
# No Salary
# Responsible for assisting the Prospect Development & Information Strategy team in the discovery, input, analysis and communication of data hosted in Raiser’s…
# 3.8
# ---------
# Google
# No Location
# No Salary
# Bachelor's degree in Computer Science, Software Engineering, other technical degree, or equivalent practical experience.
# 4.3
# ---------
# BACloudSystems
# No Location
# $65,000 - $70,000 a year
# Bacloudsystems is looking for Business analyst, who is responsible for conducting full life-cycle analysis to include requirements, activities and design.
# No rating
# ---------
# AMGTech Solutions
# No Location
# $60,000 - $70,000 a year
# AMGTech Solutions is seeking for Business Analysts, who are highly qualified individuals with a proven record of academic excellence combined with significant…
# No rating
# ---------
# AXA General Insurance
# No Location
# No Salary
# The Data Analyst will conduct full lifecycle analysis of raw information and data to include requirements, activities and design.
# 3.8
# ---------
# AP Global Operations
# No Location
# No Salary
# The Data Analyst will conduct full lifecycle analysis of raw information and data to include requirements, activities and design.
# No rating
# ---------
# Medical Home Network
# No Location
# No Salary
# The Data Analyst Intern will support the data and analytic needs of a broad range of data warehousing projects, clinical initiatives, and financial analyses.
# No rating
# ---------
# Northwestern University
# No Location
# No Salary
# Provides expertise in data management, quality assurance, analysis and reporting.Establishes data accuracy and validity derived from a variety of systems.
# 4.2
# ---------
# Rewards Network
# No Location
# No Salary
# We don’t rest on our successes.The Data Analyst Developer, as part of the Data team, will collaboratively work with business teams (Product, Marketing, Sales,…
# 3.1
# ---------
# Aaratechinc
# No Location
# $55,000 - $70,000 a year
# Data Analysis, SQL, Date warehouse.Desired Skills "Basic Healthcare experience is preferred Good Knowledge on TSQL, PL/SQL.
# No rating
# ---------
# SAC Wireless
# Chicago, IL 60661 (Near West Side area)
# No Salary
# The Sales Data Analyst will perform data mining, probability and statistics.They will help to create meaningful reporting suites to optimize business practices…
# 3.1
# ---------
# The DALE Foundation and Dental Assisting National Board, Inc ( DANB)
# Chicago, IL 60611 (Near North Side area)
# $62,000 - $87,000 a year
# We are looking for a motivated Business Systems and Data Analyst who is ready to jump in, contribute, and make a difference.The ideal candidate must have:
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=Chicago&start=10
# ---------
# The DALE Foundation and Dental Assisting National Board, Inc ( DANB)
# Chicago, IL 60611 (Near North Side area)
# $62,000 - $87,000 a year
# We are looking for a motivated Business Systems and Data Analyst who is ready to jump in, contribute, and make a difference.The ideal candidate must have: _.
# No rating
# ---------
# E*TRADE FINANCIAL
# Chicago, IL
# No Salary
# The role is part of the Data Insights & Initiatives team.As a Lead Data Analyst, you will work on programs and projects from start to end and deliver high…
# 3.6
# ---------
# United Airlines Inc.
# Chicago, IL 60601 (Loop area)
# No Salary
# Strong organization and project management skills, and strong attention to detail.This Digital Products and Analytics department consists of merchandising,…
# 4.0
# ---------
# American Board of Medical Specialties
# Chicago, IL 60601 (Loop area)
# No Salary
# Descriptive statistics: 3 years (Required).The Data Analyst supports the needs of ABMS in aggregating, cleaning, and evaluating data from sources internal and…
# 4.0
# ---------
# Technosphere, Inc.
# Chicago, IL
# No Salary
# This position will be responsible for planning and organizing key Technology Vertical meetings and events and assist in operational data analysis activities and…
# No rating
# ---------
# Uline
# Northbrook, IL
# No Salary
# Well organized and detail oriented with an ability to multitask.Talk to us about this position and learn all about our spectacular growth, generous benefits…
# 3.2
# ---------
# Chicago Public Schools
# No Location
# No Salary
# Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…
# 3.8
# ---------
# VMLY&R
# No Location
# No Salary
# The Senior Analyst will focus on reporting and analysis through the sales funnel, with a secondary emphasis on advanced analysis of survey results.
# No rating
# ---------
# BNY Mellon
# No Location
# No Salary
# Excellent attention to detail and communication skills, timekeeping, ability to troubleshoot, work on own initiative, curiosity and a drive to learn, solution…
# 3.5
# ---------
# Google
# No Location
# No Salary
# Bachelor's degree in Computer Science, Software Engineering, other technical degree or equivalent practical experience.
# 4.3
# ---------
# Vivaran IT Solutions
# No Location
# No Salary
# Work closely with business , IT teams and help team to understand and document requirements.Work with application teams, SME’s to understand source systems and…
# No rating
# ---------
# Evolent Health
# No Location
# No Salary
# Absolutely about 40% in year-over-year revenue growth in 2018 .This position also has flexibility to be performed at either our Chicago, IL or Austin, TX…
# 3.3
# ---------
# AMGTech Solutions
# No Location
# $60,000 - $70,000 a year
# AMGTech Solutions is seeking for Business Analysts, who are highly qualified individuals with a proven record of academic excellence combined with significant…
# No rating
# ---------
# Cook County Treasurer's Office
# No Location
# No Salary
# This role will be responsible for managing projects relative to Data Warehousing and Data Integration as well as Business Intelligence, Analytics and Reporting…
# No rating
# ---------
# Label Insight
# No Location
# No Salary
# About the Data Transformation Team:This team simplifies the complicated world of product data into smart, industry-forward and relevant data that powers Label…
# 3.5
# ---------
# SteelSeries
# No Location
# No Salary
# A keen attention to detail is a must.Help SteelSeries better understand the gaming peripheral market, track sales and brand performance, identify and…
# No rating
# ---------
# SAC Wireless
# Chicago, IL 60661 (Near West Side area)
# No Salary
# SUMMARY: The Sales Data Analyst will perform data mining, probability and statistics.They will help to create meaningful reporting suites to optimize business…
# 3.1
# ---------
# Aaratechinc
# Chicago, IL
# $55,000 - $70,000 a year
# Data Analysis, SQL, Date warehouse.Desired Skills "Basic Healthcare experience is preferred Good Knowledge on TSQL, PL/SQL.
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=Chicago&start=20
# ---------
# United Airlines Inc.
# Chicago, IL 60601 (Loop area)
# No Salary
# Strong organization and project management skills, and strong attention to detail.We have a wide variety of career opportunities around the world — come find…
# No rating
# ---------
# American Board of Medical Specialties
# Chicago, IL 60601 (Loop area)
# No Salary
# 3-5 years’ relevant experience.Descriptive statistics: 3 years (Required).Organized, self-motivated, results oriented, and detail-oriented.
# No rating
# ---------
# The DALE Foundation and Dental Assisting National Board, Inc ( DANB)
# Chicago, IL 60611 (Near North Side area)
# $62,000 - $87,000 a year
# We are looking for a motivated Business Systems and Data Analyst who is ready to jump in, contribute, and make a difference.The ideal candidate must have: _.
# No rating
# ---------
# E*TRADE FINANCIAL
# Chicago, IL
# No Salary
# ...
# No rating
# ---------
# KG Lewis
# Denver, CO
# No Salary
# KG Lewis is built on 16 successful years of helping businesses of all kinds navigate change, challenge, and transformation. If this sounds like you, let’s talk!
# No rating
# ---------
# CoBank
# Denver, CO
# No Salary
# Excellent analytical, diagnostic and reporting skills, with a high level accuracy and attention to detail. Partners with and specializes in a particular set of…
# No rating
# https://www.indeed.com/jobs?q=data+analyst&l=Boulder&start=70
# ---------
# Astreya Partners Inc
# No Location
# $83,000 - $121,000 a year
# Astreya is the leading IT solutions provider to deliver technology-enabled services and fuel digital transformation to some of the most exciting companies on…
# 2.7
# ---------
# ClientSolv Technologies
# No Location
# No Salary
# 3-5+ years of professional experience working with business-focused stakeholders and planning the work of software developers.
# 4.0
# ---------
# RTD
# No Location
# $67,351 - $112,252 a year
# This position acts as a liaison among stakeholders in order to elicit, analyze, communicate and validate requirements for changes to business processes,…
# 3.4
# ---------
# Quantum Spatial INC
# No Location
# No Salary
# Quantum Spatial is seeking a Geospatial Business Analyst/Data Standards Specialist to work directly with its federal government client in Lakewood, CO.
# 3.3
# ---------
# Welltok
# No Location
# No Salary
# Welltok is a data-driven, enterprise SaaS company that delivers the healthcare industry's leading consumer activation platform.
# 3.2
# ---------
# CenturyLink
# No Location
# No Salary
# The Data Governance Analyst II is responsible for performing multiple complex projects within the Finance Data Governance office in support of initiatives to…
# 3.5
# ---------
# CenturyLink
# No Location
# No Salary
# Drives Internal Audit’s use of data analysis to identify and analyze complex issues and significantly enhance the value of internal audits and management's…
# 3.5
# ---------
# Northrop Grumman
# No Location
# No Salary
# No matter the assignment, Northrop Grumman is committed to being a leader in Cyber, Logistics and Modernization, Autonomous Systems, C4ISR, and Strike.
# 4.0
# ---------
# RingCentral
# No Location
# No Salary
# We are a $650M company, disrupting the $100B business communications and collaboration market (Avaya, Cisco, Microsoft) with a killer product (Gartner MQ Leader…
# 2.5
# ---------
# FluentStream
# No Location
# No Salary
# A high degree of attention to detail and trustworthiness, with an ability to discover and remedy discrepancies. What you’ll need to have: *.
# No rating
# ---------
# Astreya
# Thornton, CO
# No Salary
# Astreya is the leading IT solutions provider to deliver technology-enabled services and fuel digital transformation to some of the most exciting companies on…
# No rating
# ---------
# Harte Hanks
# Denver, CO
# No Salary
# Minimum five (5) years’ experience. Agile/Scrum methodologies: 3 years (Preferred). Python or R: 3 years (Preferred). High-tech B2B: 3 years (Preferred).
# 3.3
# ---------
# CenturyLink
# Broomfield, CO 80021
# No Salary
# The Data Governance Analyst II is responsible for performing multiple complex projects within the Finance Data Governance office in support of initiatives to…
# 3.5
# ---------
# American Auto Shield
# Lakewood, CO
# No Salary
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail and accuracy…
# 2.8
# ---------
# KG Lewis
# Denver, CO
# No Salary
# Data Migration: 3 years (Required). ETL (Extract Transform Load): 3 years (Required). KG Lewis is built on 16 successful years of helping businesses of all…
# No rating
# ---------
# CoBank
# Denver, CO
# No Salary
# Five (5) or more years of data analytics, data management, data science, business analysis or other relevant experience; or an appropriate combination of…
# 3.3
# https://www.indeed.com/jobs?q=data+analyst&l=Boulder&start=80
# ---------
# CenturyLink
# Broomfield, CO 80021
# No Salary
# The Data Governance Analyst II is responsible for performing multiple complex projects within the Finance Data Governance office in support of initiatives to…
# 3.5
# ---------
# Maxar Technologies
# No Location
# No Salary
# Minimum of 5 years of relevant experience.Please review the job details below.Maxar is seeking a creative, enthusiastic, and motivated Geospatial Interactive…
# 3.6
# ---------
# DaVita
# No Location
# No Salary
# Are you a tech savvy burgeoning data guru with exceptional communication skills looking for an opportunity to support two of DaVita’s most exciting and…
# 3.5
# ---------
# Conga
# No Location
# No Salary
# This position will additionally partner with the Enterprise Cloud Solutions, Finance, Product, and other cross-functional teams to understand key data…
# 3.5
# ---------
# Okyte
# No Location
# No Salary
# The successful applicant will serve as the liaison between the executve ane IT eepartrents of our corpany, leveraging the eata the IT tear extrapolates while…
# No rating
# ---------
# Janus Henderson
# No Location
# No Salary
# Janus Henderson Global Investors is a leading independent global asset manager, dedicated to delivering the best outcomes for clients through a broad range of…
# 3.2
# ---------
# GHX
# No Location
# No Salary
# Minimum of 2-3 years hands on finance experience in budgeting, forecasting, financial analysis or data analysis.Learn GHX business, products, and industry.
# 3.3
# ---------
# Tanisha Systems Inc
# No Location
# No Salary
# Hope you are doing good.Please do take a look and let me know your interest for the same.Role – POS Business Analyst (Aloha).Job type- Contract to hire.
# 3.1
# ---------
# TD Ameritrade
# No Location
# No Salary
# 3-5 related experience required.This position is responsible for developing complex algorithms and using advanced modeling techniques (e.g., predictive and…
# 3.9
# ---------
# Ascentium Capital, LLC
# No Location
# No Salary
# Internship assignments will last between 3-6 months, and you will receive additional learning and personal development opportunities to supplement your…
# 3.8
# ---------
# FluentStream
# No Location
# No Salary
# A high degree of attention to detail and trustworthiness, with an ability to discover and remedy discrepancies.Bachelor’s degree or equivalent work experience.
# No rating
# ---------
# Astreya
# Thornton, CO
# No Salary
# We are looking for a Business Intelligence Analyst with SQL experience to analyze, develop, and implement code.Written descriptions in ticketing system;
# No rating
# ---------
# Harte Hanks
# Denver, CO
# No Salary
# Minimum five (5) years’ experience.Python or R: 3 years (Preferred).Harte Hanks is seeking a Data Visualization Specialist to manage the day-to-day client…
# 3.3
# ---------
# American Auto Shield
# Lakewood, CO
# No Salary
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail and accuracy…
# 2.8
# ---------
# KG Lewis
# Denver, CO
# No Salary
# KG Lewis is built on 16 successful years of helping businesses of all kinds navigate change, challenge, and transformation.Manage the data migration project.
# No rating
# ---------
# CoBank
# Denver, CO
# No Salary
# Five (5) or more years of data analytics, data management, data science, business analysis or other relevant experience;
# 3.3
# https://www.indeed.com/jobs?q=data+analyst&l=Boulder&start=90
# ---------
# Oracle
# No Location
# No Salary
# No Visa Sponsorship is available for this position.The Sales Operations Analyst will be a key member of the Sales Operations team for the Oracle Data Cloud …
# No rating
# ---------
# Sierra Nevada Corporation
# No Location
# No Salary
# SNC is currently seeking exceptional candidates who wish to be a part of the commercial space revolution.Our fun, fast-paced and collaborative team designs,…
# No rating
# ---------
# ServiceSource
# No Location
# No Salary
# Distinctive problem-solving skills, impeccable business judgment, and attention to detail.At ServiceSource, we strive to find and grow exceptional people like…
# No rating
# ---------
# PHOENIX
# No Location
# No Salary
# PHOENIX is seeking talented, hungry technology candidates interested in making the most of being groomed through direct mentorship by our CIO while working on…
# No rating
# ---------
# Analytic Partners
# No Location
# No Salary
# Analytic Partners is looking for a Marketing Science Analyst with strong analytic skills and a data-driven mindset.We value our people, clients and partners.
# No rating
# ---------
# Delta Dental of Colorado
# No Location
# No Salary
# Delta Dental of Colorado (DDCO) is the state's leading dental benefits company and the only one based in Colorado.Builds and retains a high-functioning team.
# No rating
# ---------
# Bright Horizons Family Solutions
# No Location
# No Salary
# Excellent level of attention to detail and follow-up.We’re a Fortune Magazine Top Place to Work and if you’re a top notch BI professional, we want to speak…
# No rating
# ---------
# Trace3
# No Location
# No Salary
# Trace3 is a leading Transformative IT Authority, providing unique technology solutions and consulting services to our clients.You are a crazy fast learner.
# No rating
# ---------
# CenturyLink
# No Location
# No Salary
# As a Senior Tax Data Analyst, you’ll join a dynamic team working to increase automation and transform legacy processes to positively impact the business and…
# No rating
# ---------
# CoBank
# No Location
# No Salary
# At CoBank, our Director of Information Technology directs the development and implementation of enterprise data warehouse and business intelligence initiatives.
# No rating
# ---------
# Astreya
# Thornton, CO
# No Salary
# Astreya is the leading IT solutions provider to deliver technology-enabled services and fuel digital transformation to some of the most exciting companies on…
# No rating
# ---------
# Harte Hanks
# Denver, CO
# No Salary
# Harte Hanks is seeking a Data Visualization Specialist to manage the day-to-day client relationship support on the assigned piece of business, ensuring that the…
# No rating
# ---------
# CenturyLink
# Broomfield, CO 80021
# No Salary
# The Data Governance Analyst II is responsible for performing multiple complex projects within the Finance Data Governance office in support of initiatives to…
# No rating
# ---------
# American Auto Shield
# Lakewood, CO
# No Salary
# Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail and accuracy…
# No rating
# ---------
# KG Lewis
# Denver, CO
# No Salary
# KG Lewis is built on 16 successful years of helping businesses of all kinds navigate change, challenge, and transformation.If this sounds like you, let’s talk!
# No rating
# ---------
# CoBank
# Denver, CO
# No Salary
# Excellent analytical, diagnostic and reporting skills, with a high level accuracy and attention to detail.Partners with and specializes in a particular set of…
# No rating
# [{'title': 'Business Data Analyst', 'company': 'Plowz & Mowz Inc', 'location': 'Syracuse, NY 13202 (Southwest area)', 'salary': 'No Salary', 'summary': 'PLOWZ & MOWZ, is a hot startup company in Syracuse, NY.With impressive investors and a collaborative and winning team.There\'s an app for that" - USA Today.', 'rating': 'No rating'}, {'title': 'Data Analyst', 'company': 'Fust Charles Chambers LLP', 'location': 'Syracuse, NY 13214', 'salary': 'No Salary', 'summary': '\uf0b7 Strong analytical skills with the ability to collect, organize, analyze, and disseminate significant amounts of information with attention to detail and…', 'rating': '4.8'}, {'title': 'Banking Data Analyst and Governance', 'company': 'The Bachrach Group', 'location': 'New York, NY 10001 (Chelsea area)', 'salary': '$65 - $75 an hour', 'summary': '5 years or more of relevant data management, quality and governance experience with a tier 1 bank.Understanding appropriate regulatory initiatives impacting…', 'rating': '3.6'}, {'title': 'Full Time Healthcare Quality Assurance Data Analyst', 'company': 'Bridging Access to Care, Inc', 'location': 'Brooklyn, NY', 'salary': '$65,000 a year', 'summary': 'Brooklyn based nonprofit seeks Health Quality Assurance/Data Analyst with a bachelor’s degree in with years’ experience.', 'rating': '2.5'}, {'title': 'Data Analyst', 'company': 'Aaratechinc', 'location': 'Manhattan, NY', 'salary': '$55,000 - $70,000 a year', 'summary': 'Strong analytical skills with the ability to collect, organize, analyze and disseminate significant amounts of information with attention to detail.', 'rating': 'No rating'}, {'title': 'Sr. Data Analyst', 'company': 'Noom Inc.', 'location': 'New York, NY', 'salary': 'No Salary', 'summary': 'At Noom, we use scientifically proven methods to help our users create healthier lifestyles, and manage important conditions like Type-II Diabetes, Obesity, and…', 'rating': '3.9'}, {'title': 'Entry Level Data Analyst', 'company': 'KGS Technology Group, Inc.', 'location': 'No Location', 'salary': '$50,000 - $55,000 a year', 'summary': 'Interpret data, analyze results using statistical techniques and provide ongoing reports.Develop and implement databases, data collection systems, data…', 'rating': '4.5'}, {'title': 'Entry level/ Junior/ Fresher Data Analyst', 'company': 'KGS Technology Group, Inc', 'location': 'No Location', 'salary': '$50,000 - $60,000 a year', 'summary': '_KGS Technology Group is one of the fast growing companies in IT consulting for fortune 500 clients.We cater to the application development and support…', 'rating': '4.5'}, {'title': 'Data Analyst', 'company': 'Cedar Inc', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Cedar is a patient payment and engagement platform that elevates the total patient experience beyond clinical care.Experience with query languages (e.g.', 'rating': '3.5'}, {'title': 'Junior Data Analyst', 'company': 'Medly Pharmacy', 'location': 'No Location', 'salary': '$20 - $25 an hour', 'summary': 'We’re looking for an entry-level data analyst who can turn data from multiple sources into our custom-formatted data reports.', 'rating': '3.3'}, {'title': 'DATA ANALYST', 'company': 'Montefiore Medical Center', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Creates, generates and analyzes statistical reports to track and measure various clinical functions.Troubleshoots hardware and software problems, maintains…', 'rating': '4.1'}, {'title': 'Entry Level Business Analyst', 'company': 'CloudServiceTek', 'location': 'No Location', 'salary': '$60,000 - $70,000 a year', 'summary': 'CloudServiceTek is hiring multiple Business Analysts.You will be part of a collaborative Agile team and will Analyze, Review and Document requirements for new…', 'rating': 'No rating'}, {'title': 'Analyst, Data & Insights', 'company': 'The New York Times', 'location': 'No Location', 'salary': 'No Salary', 'summary': 'Seeking analytical talent to turn passion for data and support o ...
#                         company                             location  \
# 0              Plowz & Mowz Inc  Syracuse, NY 13202 (Southwest area)
# 1     Fust Charles Chambers LLP                   Syracuse, NY 13214
# 2            The Bachrach Group    New York, NY 10001 (Chelsea area)
# 3  Bridging Access to Care, Inc                         Brooklyn, NY
# 4                   Aaratechinc                        Manhattan, NY
#
#       rating                    salary  \
# 0  No rating                 No Salary
# 1        4.8                 No Salary
# 2        3.6         $65 - $75 an hour
# 3        2.5            $65,000 a year
# 4  No rating  $55,000 - $70,000 a year
#
#                                              summary  \
# 0  PLOWZ & MOWZ, is a hot startup company in Syra...
# 1   Strong analytical skills with the ability to...
# 2  5 years or more of relevant data management, q...
# 3  Brooklyn based nonprofit seeks Health Quality ...
# 4  Strong analytical skills with the ability to c...
#
#                                                title
# 0                              Business Data Analyst
# 1                                       Data Analyst
# 2                Banking Data Analyst and Governance
# 3  Full Time Healthcare Quality Assurance Data An...
# 4                                       Data Analyst

# %%
#saving sample_df as a local csv file — define your own local path to save contents 
sample_df.to_csv("scraped_jobs.csv", encoding="utf-8")
# Out:
# /Users/michelapetrozzi/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:177: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-6ea08dfe563b> in <module>
#      28             c = soup.findAll("div", attrs={"class": "location"})
#      29             for div in c:
# ---> 30                 job_post.append(span.text)
#      31             # Web scraping summary text
#      32             divis = soup.findAll("div", attrs={"class": "summary"})
#
# NameError: name 'span' is not defined

# %%
all_df
# Out:
#                                         company  \
# 0                              Plowz & Mowz Inc
# 1                     Fust Charles Chambers LLP
# 2                            The Bachrach Group
# 3                  Bridging Access to Care, Inc
# 4                                   Aaratechinc
# 5                                     Noom Inc.
# 6                    KGS Technology Group, Inc.
# 7                     KGS Technology Group, Inc
# 8                                     Cedar Inc
# 9                                Medly Pharmacy
# 10                    Montefiore Medical Center
# 11                              CloudServiceTek
# 12                           The New York Times
# 13                                     RedRoute
# 14    Integrated Reporting is Simple (IRIS CRM)
# 15                     Quantbot Technologies LP
# 16                                     Spectrum
# 17                      Horizon Health Services
# 18                      Horizon Health Services
# 19                    Fust Charles Chambers LLP
# 20                 Bridging Access to Care, Inc
# 21           Alliant Cooperative Data Solutions
# 22                           The Bachrach Group
# 23                                    Noom Inc.
# 24                                  Aaratechinc
# 25                            Bertelsmann, Inc.
# 26                                      Comcast
# 27                                 3x3 Insights
# 28                                    LJM Group
# 29                       NYC Health + Hospitals
# ...                                         ...
# 3068                                     DaVita
# 3069                                      Conga
# 3070                                      Okyte
# 3071                            Janus Henderson
# 3072                                        GHX
# 3073                        Tanisha Systems Inc
# 3074                              TD Ameritrade
# 3075                     Ascentium Capital, LLC
# 3076                               FluentStream
# 3077                                    Astreya
# 3078                                Harte Hanks
# 3079                       American Auto Shield
# 3080                                   KG Lewis
# 3081                                     CoBank
# 3082                                     Oracle
# 3083                  Sierra Nevada Corporation
# 3084                              ServiceSource
# 3085                                    PHOENIX
# 3086                          Analytic Partners
# 3087                   Delta Dental of Colorado
# 3088           Bright Horizons Family Solutions
# 3089                                     Trace3
# 3090                                CenturyLink
# 3091                                     CoBank
# 3092                                    Astreya
# 3093                                Harte Hanks
# 3094                                CenturyLink
# 3095                       American Auto Shield
# 3096                                   KG Lewis
# 3097                                     CoBank
#
#                                     location     rating  \
# 0        Syracuse, NY 13202 (Southwest area)  No rating
# 1                         Syracuse, NY 13214        4.8
# 2          New York, NY 10001 (Chelsea area)        3.6
# 3                               Brooklyn, NY        2.5
# 4                              Manhattan, NY  No rating
# 5                               New York, NY        3.9
# 6                                No Location        4.5
# 7                                No Location        4.5
# 8                                No Location        3.5
# 9                                No Location        3.3
# 10                               No Location        4.1
# 11                               No Location  No rating
# 12                               No Location        4.0
# 13                               No Location  No rating
# 14                               No Location  No rating
# 15                               No Location  No rating
# 16    New York, NY 10012 (Little Italy area)        3.5
# 17                       Getzville, NY 14068        3.1
# 18                       Getzville, NY 14068  No rating
# 19                        Syracuse, NY 13214  No rating
# 20                              Brooklyn, NY  No rating
# 21                              Brewster, NY  No rating
# 22         New York, NY 10001 (Chelsea area)  No rating
# 23                              New York, NY  No rating
# 24                             Manhattan, NY  No rating
# 25                               No Location  No rating
# 26                               No Location  No rating
# 27                               No Location  No rating
# 28                               No Location  No rating
# 29                               No Location  No rating
# ...                                      ...        ...
# 3068                             No Location        3.5
# 3069                             No Location        3.5
# 3070                             No Location  No rating
# 3071                             No Location        3.2
# 3072                             No Location        3.3
# 3073                             No Location        3.1
# 3074                             No Location        3.9
# 3075                             No Location        3.8
# 3076                             No Location  No rating
# 3077                            Thornton, CO  No rating
# 3078                              Denver, CO        3.3
# 3079                            Lakewood, CO        2.8
# 3080                              Denver, CO  No rating
# 3081                              Denver, CO        3.3
# 3082                             No Location  No rating
# 3083                             No Location  No rating
# 3084                             No Location  No rating
# 3085                             No Location  No rating
# 3086                             No Location  No rating
# 3087                             No Location  No rating
# 3088                             No Location  No rating
# 3089                             No Location  No rating
# 3090                             No Location  No rating
# 3091                             No Location  No rating
# 3092                            Thornton, CO  No rating
# 3093                              Denver, CO  No rating
# 3094                    Broomfield, CO 80021  No rating
# 3095                            Lakewood, CO  No rating
# 3096                              Denver, CO  No rating
# 3097                              Denver, CO  No rating
#
#                         salary  \
# 0                    No Salary
# 1                    No Salary
# 2            $65 - $75 an hour
# 3               $65,000 a year
# 4     $55,000 - $70,000 a year
# 5                    No Salary
# 6     $50,000 - $55,000 a year
# 7     $50,000 - $60,000 a year
# 8                    No Salary
# 9            $20 - $25 an hour
# 10                   No Salary
# 11    $60,000 - $70,000 a year
# 12                   No Salary
# 13    $65,000 - $95,000 a year
# 14    $55,000 - $70,000 a year
# 15                   No Salary
# 16                   No Salary
# 17                   No Salary
# 18                   No Salary
# 19                   No Salary
# 20              $65,000 a year
# 21                   No Salary
# 22           $65 - $75 an hour
# 23                   No Salary
# 24    $55,000 - $70,000 a year
# 25                   No Salary
# 26                   No Salary
# 27           $15 - $25 an hour
# 28                   No Salary
# 29                   No Salary
# ...                        ...
# 3068                 No Salary
# 3069                 No Salary
# 3070                 No Salary
# 3071                 No Salary
# 3072                 No Salary
# 3073                 No Salary
# 3074                 No Salary
# 3075                 No Salary
# 3076                 No Salary
# 3077                 No Salary
# 3078                 No Salary
# 3079                 No Salary
# 3080                 No Salary
# 3081                 No Salary
# 3082                 No Salary
# 3083                 No Salary
# 3084                 No Salary
# 3085                 No Salary
# 3086                 No Salary
# 3087                 No Salary
# 3088                 No Salary
# 3089                 No Salary
# 3090                 No Salary
# 3091                 No Salary
# 3092                 No Salary
# 3093                 No Salary
# 3094                 No Salary
# 3095                 No Salary
# 3096                 No Salary
# 3097                 No Salary
#
#                                                 summary  \
# 0     PLOWZ & MOWZ, is a hot startup company in Syra...
# 1      Strong analytical skills with the ability to...
# 2     5 years or more of relevant data management, q...
# 3     Brooklyn based nonprofit seeks Health Quality ...
# 4     Strong analytical skills with the ability to c...
# 5     At Noom, we use scientifically proven methods ...
# 6     Interpret data, analyze results using statisti...
# 7     _KGS Technology Group is one of the fast growi...
# 8     Cedar is a patient payment and engagement plat...
# 9     We’re looking for an entry-level data analyst ...
# 10    Creates, generates and analyzes statistical re...
# 11    CloudServiceTek is hiring multiple Business An...
# 12    Seeking analytical talent to turn passion for ...
# 13    RedRoute is paving the path to amazing voice-e...
# 14    On a scale of 1 to 5, with 5 being expert, how...
# 15    A global finance company is looking for an Ent...
# 16    Spectrum Reach (www.spectrumreach.com) grows b...
# 17    Horizon Health Services is a not-for-profit co...
# 18    The Data Analyst will work under the Business ...
# 19     Strong analytical skills with the ability to...
# 20    Brooklyn based nonprofit seeks Health Quality ...
# 21    Data Analyst: 5 years (Required).Must be a cri...
# 22    Understanding appropriate regulatory initiativ...
# 23    We are looking for a Sr. Data Analyst to join ...
# 24    Strong analytical skills with the ability to c...
# 25    As a Data Science Intern in the newly formed N...
# 26    This data analyst will work with our Product a...
# 27    Data Mapping Analyst – Part Time.3x3 Insights ...
# 28    We are a B2B Consulting Firm within the Logist...
# 29    The IT Core Systems Data Quality Analyst (DQA)...
# ...                                                 ...
# 3068  Are you a tech savvy burgeoning data guru with...
# 3069  This position will additionally partner with t...
# 3070  The successful applicant will serve as the lia...
# 3071  Janus Henderson Global Investors is a leading ...
# 3072  Minimum of 2-3 years hands on finance experien...
# 3073  Hope you are doing good.Please do take a look ...
# 3074  3-5 related experience required.This position ...
# 3075  Internship assignments will last between 3-6 m...
# 3076  A high degree of attention to detail and trust...
# 3077  We are looking for a Business Intelligence Ana...
# 3078  Minimum five (5) years’ experience.Python or R...
# 3079  Strong analytical skills with the ability to c...
# 3080  KG Lewis is built on 16 successful years of he...
# 3081  Five (5) or more years of data analytics, data...
# 3082  No Visa Sponsorship is available for this posi...
# 3083  SNC is currently seeking exceptional candidate...
# 3084  Distinctive problem-solving skills, impeccable...
# 3085  PHOENIX is seeking talented, hungry technology...
# 3086  Analytic Partners is looking for a Marketing S...
# 3087  Delta Dental of Colorado (DDCO) is the state's...
# 3088  Excellent level of attention to detail and fol...
# 3089  Trace3 is a leading Transformative IT Authorit...
# 3090  As a Senior Tax Data Analyst, you’ll join a dy...
# 3091  At CoBank, our Director of Information Technol...
# 3092  Astreya is the leading IT solutions provider t...
# 3093  Harte Hanks is seeking a Data Visualization Sp...
# 3094  The Data Governance Analyst II is responsible ...
# 3095  Strong analytical skills with the ability to c...
# 3096  KG Lewis is built on 16 successful years of he...
# 3097  Excellent analytical, diagnostic and reporting...
#
#                                                   title
# 0                                 Business Data Analyst
# 1                                          Data Analyst
# 2                   Banking Data Analyst and Governance
# 3     Full Time Healthcare Quality Assurance Data An...
# 4                                          Data Analyst
# 5                                      Sr. Data Analyst
# 6                              Entry Level Data Analyst
# 7             Entry level/ Junior/ Fresher Data Analyst
# 8                                          Data Analyst
# 9                                   Junior Data Analyst
# 10                                         DATA ANALYST
# 11                         Entry Level Business Analyst
# 12                             Analyst, Data & Insights
# 13                                         Data Analyst
# 14                                         Data Analyst
# 15     Entry-Level Intern to Hire Junior Data Analytics
# 16                 Data and Attribution Analyst - Media
# 17                                         Data Analyst
# 18                                         Data Analyst
# 19                                         Data Analyst
# 20    Full Time Healthcare Quality Assurance Data An...
# 21                              Senior ETL Data Analyst
# 22                  Banking Data Analyst and Governance
# 23                                     Sr. Data Analyst
# 24                                         Data Analyst
# 25                                  Data Science Intern
# 26                           Tech Intern - Data Analyst
# 27                Alcohol Products Data Mapping Analyst
# 28                                         Data Analyst
# 29                                 Data Quality Analyst
# ...                                                 ...
# 3068                                       Data Analyst
# 3069                 Sales Operations Reporting Analyst
# 3070                                   BUSINESS ANALYST
# 3071                                   Business Analyst
# 3072                                  Financial Analyst
# 3073                       POS Business Analyst (Aloha)
# 3074                        Senior Data Science Analyst
# 3075                              Data Analytics Intern
# 3076                                   Business Analyst
# 3077           Business Intelligence Analyst - Thornton
# 3078                      Data Visualization Specialist
# 3079                                       Data Analyst
# 3080                 Data Conversion Consultant/Analyst
# 3081                      Senior/Data Solutions Analyst
# 3082                           Sales Operations Analyst
# 3083                             Sr. Operations Analyst
# 3084                    Business Intelligence Analyst 1
# 3085                                IT Business Analyst
# 3086                          Marketing Science Analyst
# 3087                     Director of Data and Analytics
# 3088  Business Intelligence Reporting Specialist (en...
# 3089             Research Analyst - Emerging Technology
# 3090                            Senior Tax Data Analyst
# 3091  Director, Information Technology - Data Wareho...
# 3092           Business Intelligence Analyst - Thornton
# 3093                      Data Visualization Specialist
# 3094        Data Governance Analyst II - Broomfield, CO
# 3095                                       Data Analyst
# 3096                 Data Conversion Consultant/Analyst
# 3097                      Senior/Data Solutions Analyst
#
# [3098 rows x 6 columns]

# %%
all_df.to_csv("scraped_jobs.csv", encoding="utf-8")
